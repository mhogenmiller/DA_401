# %%
# !pip install pytrends #installing the pytrends package

#Make into a function so that it works with many shows and dates 
#Add the show as a column
#Ultimate goal is to get it into the OG data set
# Out:
# Requirement already satisfied: pytrends in /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages (4.4.0)
# Requirement already satisfied: lxml in /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages (from pytrends) (3.7.3)
# Requirement already satisfied: requests in /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages (from pytrends) (2.18.4)
# Requirement already satisfied: pandas in /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages (from pytrends) (0.20.1)
# Requirement already satisfied: idna<2.7,>=2.5 in /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages (from requests->pytrends) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages (from requests->pytrends) (2018.4.16)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages (from requests->pytrends) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages (from requests->pytrends) (3.0.4)
# Requirement already satisfied: python-dateutil>=2 in /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages (from pandas->pytrends) (2.6.1)
# Requirement already satisfied: pytz>=2011k in /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages (from pandas->pytrends) (2017.2)
# Requirement already satisfied: numpy>=1.7.0 in /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages (from pandas->pytrends) (1.14.3)
# Requirement already satisfied: six>=1.5 in /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages (from python-dateutil>=2->pandas->pytrends) (1.11.0)
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from pytrends.request import TrendReq
pytrend = TrendReq()

# %%
pytrend = TrendReq(hl='en-US', tz=360)

# %% [markdown]
# ## Add date as a parameter ##
# ## Try Scraping from DidHeLikeIt?##

# %%
from datetime import datetime, timedelta
import pandas as pd
import numpy as np


#First, figure out how to get it so that it gets weekly averages and weeks as obs. so easily added into CORGI
#Get all of the starting dates from the other data set so that you don't have to enter them manually and run the function
#as many times as there 
#Make this a function (#Trying to run this in a loop so that each show can just be entered into a list)
#def show_searches (show, year, month, date):
list_of_shows= ['Hamilton','Waitress']

for i in list_of_shows:
    
    kw_list = [i] #can increase/decrease the list size 
    num_keywords = 1 #change this if you increase/decrease the list size

    #initialize date
    year = 2016
    month = 1
    date = 1
    new_date = datetime(year, month, date).date()

    # Name excel sheet the key word
    writer = pd.ExcelWriter(''.join([i,'2','.xlsx']))
    col = 1

    while(1):

      old_date = new_date  
      if(int(month/12) > 0):
        year = year+1
      month = (month+1)%13
      if(month==0):
        month += 1
      new_date = datetime(year,month,date).date()

      # Year and Month till you need the output - Change this to 2018 if you need it till present date
      #If you set month to 13, it goes until current day..good to note...will work for the shows that are still running
      if(year > 2018 and month == 2 ):
        break

      timeframe = old_date.strftime('%Y-%m-%d')+' '+ new_date.strftime('%Y-%m-%d')
      print("DATE:",timeframe)

      pytrend.build_payload(kw_list, cat=0, timeframe = timeframe,geo='US', gprop='')

      # Interest over time in one year
      data= pytrend.interest_over_time()
      df=pd.DataFrame({'mean':[np.mean(data[data.columns[0]])]})
      mean=np.mean(data[data.columns[0]])
      #print(df)
      print("\n\n")

      ## WRITE THE DATA IN AN EXCEL SHEET

      # Change the names of the columns in the data set to have show name and date
     # data = data.rename(columns={i: ' '.join([i, old_date.strftime('%Y-%m-%d')])}) #original
      data = df.rename(columns={'mean': ' '.join([i, old_date.strftime('%Y-%m-%d')])})
      print(data)
        
      #data=data.transpose()
      #print("List of columns:",list(data.columns.values))
      #print("Data size:", data.shape)
      if(col==1):
          data.to_excel(writer,'sheet1',index=True ,startcol = col-1)
      data.to_excel(writer,'sheet1',index=False ,startcol = col)
      col = col + num_keywords
    writer.save()
# Out:
# DATE: 2016-01-01 2016-02-01
#
#
#
#    Hamilton 2016-01-01
# 0             78.09375
# DATE: 2016-02-01 2016-03-01
#
#
#
#    Hamilton 2016-02-01
# 0            22.133333
# DATE: 2016-03-01 2016-04-01
#
#
#
#    Hamilton 2016-03-01
# 0             78.53125
# DATE: 2016-04-01 2016-05-01
#
#
#
#    Hamilton 2016-04-01
# 0            84.193548
# DATE: 2016-05-01 2016-06-01
#
#
#
#    Hamilton 2016-05-01
# 0               78.375
# DATE: 2016-06-01 2016-07-01
#
#
#
#    Hamilton 2016-06-01
# 0            37.645161
# DATE: 2016-07-01 2016-08-01
#
#
#
#    Hamilton 2016-07-01
# 0              65.5625
# DATE: 2016-08-01 2016-09-01
#
#
#
#    Hamilton 2016-08-01
# 0               87.875
# DATE: 2016-09-01 2016-10-01
#
#
#
#    Hamilton 2016-09-01
# 0            89.322581
# DATE: 2016-10-01 2016-11-01
#
#
#
#    Hamilton 2016-10-01
# 0              51.6875
# DATE: 2016-11-01 2016-12-01
#
#
#
#    Hamilton 2016-11-01
# 0            38.645161
# DATE: 2016-12-01 2017-01-01
#
#
#
#    Hamilton 2016-12-01
# 0              79.6875
# DATE: 2017-01-01 2017-02-01
#
#
#
#    Hamilton 2017-01-01
# 0             87.46875
# DATE: 2017-02-01 2017-03-01
#
#
#
#    Hamilton 2017-02-01
# 0            80.896552
# DATE: 2017-03-01 2017-04-01
#
#
#
#    Hamilton 2017-03-01
# 0                 90.5
# DATE: 2017-04-01 2017-05-01
#
#
#
#    Hamilton 2017-04-01
# 0            68.967742
# DATE: 2017-05-01 2017-06-01
#
#
#
#    Hamilton 2017-05-01
# 0             88.21875
# DATE: 2017-06-01 2017-07-01
#
#
#
#    Hamilton 2017-06-01
# 0            87.096774
# DATE: 2017-07-01 2017-08-01
#
#
#
#    Hamilton 2017-07-01
# 0             91.96875
# DATE: 2017-08-01 2017-09-01
#
#
#
#    Hamilton 2017-08-01
# 0              87.1875
# DATE: 2017-09-01 2017-10-01
#
#
#
#    Hamilton 2017-09-01
# 0            84.032258
# DATE: 2017-10-01 2017-11-01
#
#
#
#    Hamilton 2017-10-01
# 0                 90.0
# DATE: 2017-11-01 2017-12-01
#
#
#
#    Hamilton 2017-11-01
# 0            80.451613
# DATE: 2017-12-01 2018-01-01
#
#
#
#    Hamilton 2017-12-01
# 0             90.78125
# DATE: 2018-01-01 2018-02-01
#
#
#
#    Hamilton 2018-01-01
# 0             80.59375
# DATE: 2018-02-01 2018-03-01
#
#
#
#    Hamilton 2018-02-01
# 0             69.37931
# DATE: 2018-03-01 2018-04-01
#
#
#
#    Hamilton 2018-03-01
# 0             79.78125
# DATE: 2018-04-01 2018-05-01
#
#
#
#    Hamilton 2018-04-01
# 0            84.451613
# DATE: 2018-05-01 2018-06-01
#
#
#
#    Hamilton 2018-05-01
# 0             92.96875
# DATE: 2018-06-01 2018-07-01
#
#
#
#    Hamilton 2018-06-01
# 0            88.354839
# DATE: 2018-07-01 2018-08-01
#
#
#
#    Hamilton 2018-07-01
# 0              83.0625
# DATE: 2018-08-01 2018-09-01
#
#
#
#    Hamilton 2018-08-01
# 0                 84.5
# DATE: 2018-09-01 2018-10-01
#
#
#
#    Hamilton 2018-09-01
# 0            86.967742
# DATE: 2018-10-01 2018-11-01
#
#
#
#    Hamilton 2018-10-01
# 0                83.25
# DATE: 2018-11-01 2018-12-01
#
#
#
#    Hamilton 2018-11-01
# 0            79.483871
# DATE: 2018-12-01 2019-01-01
#
#
#
#    Hamilton 2018-12-01
# 0              72.6875
# DATE: 2016-01-01 2016-02-01
#
#
#
#    Waitress 2016-01-01
# 0              57.0625
# DATE: 2016-02-01 2016-03-01
#
#
#
#    Waitress 2016-02-01
# 0                 51.0
# DATE: 2016-03-01 2016-04-01
#
#
#
#    Waitress 2016-03-01
# 0              72.8125
# DATE: 2016-04-01 2016-05-01
#
#
#
#    Waitress 2016-04-01
# 0            67.774194
# DATE: 2016-05-01 2016-06-01
#
#
#
#    Waitress 2016-05-01
# 0                 82.5
# DATE: 2016-06-01 2016-07-01
#
#
#
#    Waitress 2016-06-01
# 0            25.741935
# DATE: 2016-07-01 2016-08-01
#
#
#
#    Waitress 2016-07-01
# 0              81.5625
# DATE: 2016-08-01 2016-09-01
#
#
#
#    Waitress 2016-08-01
# 0              84.8125
# DATE: 2016-09-01 2016-10-01
#
#
#
#    Waitress 2016-09-01
# 0            87.645161
# DATE: 2016-10-01 2016-11-01
#
#
#
#    Waitress 2016-10-01
# 0             69.21875
# DATE: 2016-11-01 2016-12-01
#
#
#
#    Waitress 2016-11-01
# 0            43.516129
# DATE: 2016-12-01 2017-01-01
#
#
#
#    Waitress 2016-12-01
# 0              67.4375
# DATE: 2017-01-01 2017-02-01
#
#
#
#    Waitress 2017-01-01
# 0             72.28125
# DATE: 2017-02-01 2017-03-01
#
#
#
#    Waitress 2017-02-01
# 0             52.62069
# DATE: 2017-03-01 2017-04-01
#
#
#
#    Waitress 2017-03-01
# 0             80.84375
# DATE: 2017-04-01 2017-05-01
#
#
#
#    Waitress 2017-04-01
# 0            84.193548
# DATE: 2017-05-01 2017-06-01
#
#
#
#    Waitress 2017-05-01
# 0             69.09375
# DATE: 2017-06-01 2017-07-01
#
#
#
#    Waitress 2017-06-01
# 0            74.064516
# DATE: 2017-07-01 2017-08-01
#
#
#
#    Waitress 2017-07-01
# 0             72.28125
# DATE: 2017-08-01 2017-09-01
#
#
#
#    Waitress 2017-08-01
# 0              79.3125
# DATE: 2017-09-01 2017-10-01
#
#
#
#    Waitress 2017-09-01
# 0            71.548387
# DATE: 2017-10-01 2017-11-01
#
#
#
#    Waitress 2017-10-01
# 0             79.90625
# DATE: 2017-11-01 2017-12-01
#
#
#
#    Waitress 2017-11-01
# 0            75.483871
# DATE: 2017-12-01 2018-01-01
#
#
#
#    Waitress 2017-12-01
# 0                 76.5
# DATE: 2018-01-01 2018-02-01
#
#
#
#    Waitress 2018-01-01
# 0              78.6875
# DATE: 2018-02-01 2018-03-01
#
#
#
#    Waitress 2018-02-01
# 0            67.137931
# DATE: 2018-03-01 2018-04-01
#
#
#
#    Waitress 2018-03-01
# 0             79.46875
# DATE: 2018-04-01 2018-05-01
#
#
#
#    Waitress 2018-04-01
# 0            80.354839
# DATE: 2018-05-01 2018-06-01
#
#
#
#    Waitress 2018-05-01
# 0                 80.5
# DATE: 2018-06-01 2018-07-01
#
#
#
#    Waitress 2018-06-01
# 0            61.064516
# DATE: 2018-07-01 2018-08-01
#
#
#
#    Waitress 2018-07-01
# 0             32.59375
# DATE: 2018-08-01 2018-09-01
#
#
#
#    Waitress 2018-08-01
# 0             79.40625
# DATE: 2018-09-01 2018-10-01
#
#
#
#    Waitress 2018-09-01
# 0            49.225806
# DATE: 2018-10-01 2018-11-01
#
#
#
#    Waitress 2018-10-01
# 0              79.9375
# DATE: 2018-11-01 2018-12-01
#
#
#
#    Waitress 2018-11-01
# 0            79.774194
# DATE: 2018-12-01 2019-01-01
#
#
#
#    Waitress 2018-12-01
# 0             75.46875

# %%
#Gathering monthy mean of data
data.columns[0]
#d=list(data['Waitress 2018-12-01'])
#month_mean = np.mean(d)
#month_mean

# %%
data[0:1]
