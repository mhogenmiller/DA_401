# %% [markdown]
# ## Practicing data redemption for one Wikipedia page ##

# %%
#Adding Packages
import requests as rq
import json
import os
import wikipedia
from urllib.request import urlopen
import pandas as pd
from bs4 import BeautifulSoup
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statsmodels.api as sm
url = "https://en.wikipedia.org/w/api.php?format=json&action=query&titles=Hamilton&prop=revisions&rvprop=content"
data = rq.get(url).json()
bfile = open('Hamilton.txt', 'w+')
json.dump(data, bfile)
bfile.close()
# Out:
# /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Referencing List of Broadway Shows Since 2010, CORGI ##

# %%
Broadway_Original = pd.read_csv('/Users/morganhogenmiller/Desktop/DA 401/Data sets/broadway(corgi).csv') #Read in CORGI data set

# %%
Google_Parameters= Broadway_Original[['Name','Year','Month','Day','Type']] #Reduce data set to variables to input into GT

#Filter to shows after 2010 only
Google_Parameters=Google_Parameters.loc[Google_Parameters['Year']>2007] 
Google_Parameters=Google_Parameters.loc[Google_Parameters['Type']=='Musical']

# %%
#Provides a list of shows in form needed for function 
show_list=list(Google_Parameters.Name.unique()) 
show_list.sort() #in alphabetical order

# %% [markdown]
# ## Counting number of articles within Wikipedia category for Broadway musicals##

# %%
#To clean, make something that says if it begins with Category, take it out
def categories(category):
    """This function takes a Wikipedia category as an input and outputs the number of Wikipedia
    articles that exist in that category."""
    count = "0"
    articles = list()

    # Loop through each musical and update count each time
    while True:
        url = "https://en.wikipedia.org/w/api.php?format=json&action=query&list=categorymembers&cmtitle=Category:"+category+"&cmlimit=500&prop=revisions&rvprop=content&cmcontinue="+ count
        data = rq.get(url).json()
        articles.extend(data['query']['categorymembers'])
        try:
            count = data['continue']['cmcontinue']
        except:
            break

    # Get the heroes and villains and ambiguous's names from the data
    articles = [x['title'] for x in articles]

    return("Number of articles in the "+ category + " category: "+ str(len(articles)), articles)

# %%
results=categories('Broadway_musicals')
articles=results[1] # creating an object for the list of musical titles
#categories('Tony_Award_Winning_musicals')
articles
# Out:
# ['9 to 5 (musical)',
#  '13 (musical)',
#  '13 Daughters',
#  'The 25th Annual Putnam County Spelling Bee',
#  '42nd Street (musical)',
#  '70, Girls, 70',
#  '110 in the Shade',
#  '1492 Up To Date',
#  '1600 Pennsylvania Avenue (musical)',
#  '1776 (musical)',
#  "The 1940's Radio Hour",
#  'A Parisian Model',
#  'The Act (musical)',
#  'The Addams Family (musical)',
#  'Adele (musical)',
#  'Adonis (musical)',
#  'The Adventures of Tom Sawyer (musical)',
#  'Afgar',
#  'After Midnight (musical)',
#  'Aida (musical)',
#  "Ain't Misbehavin' (musical)",
#  "Ain't Supposed to Die a Natural Death",
#  "Ain't Too Proud (musical)",
#  'Aladdin (2011 musical)',
#  'Alive and Kicking (musical)',
#  'All American (musical)',
#  'All Shook Up (musical)',
#  'Allegiance (musical)',
#  'Allegro (musical)',
#  'Amazing Grace (musical)',
#  'Ambassador (musical)',
#  'Amélie (musical)',
#  'Amen Corner (musical)',
#  "America's Sweetheart (musical)",
#  'American Dance Machine',
#  'American Idiot (musical)',
#  'American Psycho (musical)',
#  'Americana (revue)',
#  'Amour (musical)',
#  'An American in Paris (musical)',
#  'Anastasia (musical)',
#  'Angel (musical)',
#  'Angel in the Wings',
#  'Animal Crackers (musical)',
#  'Ankles Aweigh',
#  'Anna Karenina (musical)',
#  'Annie (musical)',
#  'Annie Get Your Gun (musical)',
#  'Anya (musical)',
#  'Anyone Can Whistle',
#  'Anything Goes',
#  'Applause (musical)',
#  'The Apple Tree',
#  'Are You with It? (musical)',
#  'Around the World (musical)',
#  'As the Girls Go',
#  'As Thousands Cheer',
#  'Aspects of Love',
#  'Assassins (musical)',
#  'At Home Abroad',
#  'Avenue Q',
#  'Babes in Arms',
#  'Babes in Toyland (operetta)',
#  'Baby (musical)',
#  "Baby It's You!",
#  'Bajour (musical)',
#  'Baker Street (musical)',
#  'Ballroom (musical)',
#  'The Band Wagon (musical)',
#  "The Band's Visit (musical)",
#  'Bandanna Land',
#  'Bandstand (musical)',
#  'Banjo Eyes',
#  'Barnum (musical)',
#  'Be More Chill (musical)',
#  'Beatlemania (musical)',
#  'Beautiful: The Carole King Musical',
#  'Beauty and the Beast (musical)',
#  "Beggar's Holiday",
#  'The Belle of New York (musical)',
#  'La Belle Paree',
#  'Bells Are Ringing (musical)',
#  'Ben Franklin in Paris',
#  'Best Foot Forward (musical)',
#  'The Best Little Whorehouse Goes Public',
#  'The Best Little Whorehouse in Texas',
#  "The Better 'Ole",
#  'Between the Devil',
#  'Big (musical)',
#  'Big Deal (musical)',
#  'Big Fish (musical)',
#  'Big River (musical)',
#  'Billion Dollar Baby',
#  'The Billy Barnes Revue',
#  'Billy Elliot the Musical',
#  'Black and Blue (musical)',
#  'The Black Crook',
#  'Blackbirds of 1928',
#  'Blackbirds of 1933',
#  'Blood Brothers (musical)',
#  'Bloomer Girl',
#  'Blue Monday (opera)',
#  'The Blue Paradise',
#  'Blues in the Night (musical)',
#  'The Body Beautiful',
#  'Bombay Dreams',
#  'Bombo (musical)',
#  'Bombshell (musical)',
#  'Bonnie & Clyde (musical)',
#  'The Book of Mormon (musical)',
#  'The Boy Friend (musical)',
#  'The Boy from Oz',
#  'The Boys from Syracuse',
#  'Bravo Giovanni',
#  "Breakfast at Tiffany's (musical)",
#  'The Bridges of Madison County (musical)',
#  'Brigadoon',
#  'Bright Lights of 1944',
#  'Bright Star (musical)',
#  'Bring Back Birdie',
#  "Bring in 'da Noise, Bring in 'da Funk",
#  'Bring It On: The Musical',
#  'A Broadway Musical',
#  'A Bronx Tale (musical)',
#  'Brooklyn (musical)',
#  'Bubbling Brown Sugar',
#  'Buddies (play)',
#  'Buddy – The Buddy Holly Story',
#  'Bugs Bunny on Broadway',
#  'Bullets Over Broadway (musical)',
#  'The Bunch and Judy',
#  'But Never Jam Today',
#  'By Jeeves',
#  'By Jupiter',
#  'By the Beautiful Sea (musical)',
#  'Bye Bye Birdie',
#  'Cabaret (musical)',
#  'Cabin in the Sky (musical)',
#  'Cafe Crown',
#  'La Cage aux Folles (musical)',
#  'Call Me Madam',
#  'Call Me Mister',
#  'Camelot (musical)',
#  'Can-Can (musical)',
#  'Candide (operetta)',
#  'Canterbury Tales (musical)',
#  'The Capeman',
#  'Carmelina',
#  'Carmen Jones',
#  'Carnival in Flanders (musical)',
#  'Carnival!',
#  'Caroline, or Change',
#  'Carousel (musical)',
#  'Carrie (musical)',
#  'Castles in the Air (play)',
#  'The Cat and the Fiddle (musical)',
#  'Catch Me If You Can (musical)',
#  'Catch My Soul (UK stage version)',
#  'A Catered Affair',
#  'Cats (musical)',
#  'Celebration (musical)',
#  'Chaplin (2006 musical)',
#  'Charlie and Algernon',
#  'Charlie and the Chocolate Factory (musical)',
#  'Chee-Chee (musical)',
#  'The Cher Show (musical)',
#  'Chess (musical)',
#  'Chicago (musical)',
#  "Chita Rivera: The Dancer's Life",
#  'Chitty Chitty Bang Bang (musical)',
#  'A Chorus Line',
#  'Christine (musical)',
#  'A Christmas Story: The Musical',
#  'Chronicle of a Death Foretold (musical)',
#  'Chu Chem',
#  'Cinderella (2013 Broadway production)',
#  'Cinderella (musical)',
#  'City of Angels (musical)',
#  'The Civil War (musical)',
#  'A Class Act',
#  'Clorindy: The Origin of the Cakewalk',
#  'Coco (musical)',
#  'The Cocoanuts (musical)',
#  'The Color Purple (musical)',
#  'Come Fly Away',
#  'Come from Away',
#  'Come Summer',
#  'Company (musical)',
#  'A Connecticut Yankee (musical)',
#  'The Conquering Hero',
#  'Contact (musical)',
#  'Copperfield (musical)',
#  'A Country Girl',
#  'The Cradle Will Rock',
#  'Crazy for You (musical)',
#  'The Crinoline Girl',
#  'Criss Cross (musical)',
#  'Cry for Us All',
#  'Cry-Baby (musical)',
#  'Curtains (musical)',
#  'Cyrano (musical)',
#  'Cyrano: The Musical',
#  'Dames at Sea',
#  'Damn Yankees',
#  'Dance a Little Closer',
#  'Dance of the Vampires (musical)',
#  'Dance with Me (musical)',
#  "Dancin'",
#  'Darling of the Day',
#  'The Day Before Spring',
#  'A Day in Hollywood / A Night in the Ukraine',
#  'Dear Evan Hansen',
#  'Dear World',
#  'Dearest Enemy',
#  'The Desert Song',
#  'Destry Rides Again (musical)',
#  'Dew Drop Inn (musical)',
#  'Different Times (musical)',
#  'Dirty Rotten Scoundrels (musical)',
#  'Disaster! (musical)',
#  'The District Leader',
#  'Divine Lust',
#  'Do Black Patent Leather Shoes Really Reflect Up?',
#  'Do I Hear a Waltz?',
#  'Do Re Mi (musical)',
#  'Doctor Zhivago (musical)',
#  "A Doll's Life",
#  "Don't Bother Me, I Can't Cope",
#  "Don't Play Us Cheap",
#  "Don't Step on My Olive Branch",
#  "Don't Stop 'Til You Get Enough (musical)",
#  'Donnybrook!',
#  'Doonesbury (musical)',
#  'Rap Master Ronnie',
#  "Dr. Seuss' How the Grinch Stole Christmas! The Musical",
#  'Dracula, the Musical',
#  'Drat! The Cat!',
#  'Dream (musical)',
#  'The Dream Girl (operetta)',
#  'Dreamgirls',
#  'Dreamtime (musical)',
#  'Das Dreimäderlhaus',
#  'Drood',
#  'The Drowsy Chaperone',
#  'DuBarry Was a Lady',
#  'Dude (musical)',
#  'The Education of H*Y*M*A*N K*A*P*L*A*N',
#  'Eileen (musical)',
#  'Elf (musical)',
#  'Escape to Margaritaville',
#  'Eubie!',
#  'An Evening with Jerry Herman',
#  "Everybody's Welcome",
#  'Everyday Rapture',
#  'Evita (musical)',
#  'Face the Music (musical)',
#  'Fade Out – Fade In',
#  'Falsettos',
#  'A Family Affair (musical)',
#  'Fanny (musical)',
#  'The Fascinating Widow',
#  'Fiddler on the Roof',
#  'Fifty Million Frenchmen',
#  'The Fig Leaves Are Falling',
#  "Finian's Rainbow",
#  'Fiorello!',
#  'The Firebrand of Florence',
#  'The Firefly (operetta)',
#  'First Date (musical)',
#  'First Impressions (musical)',
#  'The First (musical)',
#  'Five Guys Named Moe',
#  "The Five O'Clock Girl",
#  'Flahooley',
#  'Flora the Red Menace',
#  'Florodora',
#  'Flower Drum Song',
#  'Flying Colors (musical)',
#  'Flying High (musical)',
#  'Follies',
#  'Follow the Girls',
#  'Follow Thru (musical)',
#  'Footloose (musical)',
#  'The Fortune Teller (operetta)',
#  'Forty-five Minutes from Broadway',
#  'Fosse (musical)',
#  'Foxy (musical)',
#  'The Frogs (musical)',
#  'From A to Z',
#  'Frozen (musical)',
#  'The Full Monty (musical)',
#  'Fun Home (musical)',
#  'Funny Face (musical)',
#  'Funny Girl (musical)',
#  'A Funny Thing Happened on the Way to the Forum',
#  'Gantry (musical)',
#  'The Garrick Gaieties',
#  'Gay Divorce',
#  'The Gay Life',
#  "A Gentleman's Guide to Love and Murder",
#  'Gentlemen Prefer Blondes (musical)',
#  'George M!',
#  "George White's Scandals",
#  'Georgy (musical)',
#  'Ghost the Musical',
#  'Gigi (musical)',
#  'Girl Crazy',
#  'The Girl Friend',
#  'The Girl from Nantucket',
#  'The Gay Parisienne',
#  'The Girl in Pink Tights',
#  'The Girl in the Taxi (play)',
#  'The Girl Who Came to Supper',
#  'Glory Days (musical)',
#  'Godspell',
#  'Going Up (musical)',
#  'The Golden Apple (musical)',
#  'Golden Boy (musical)',
#  'Golden Rainbow (musical)',
#  'Goldilocks (musical)',
#  'Good News (musical)',
#  'Good Times (musical)',
#  'Good Vibrations (musical)',
#  'The Goodbye Girl (musical)',
#  'Goodtime Charley',
#  'The Gospel at Colonus',
#  'Grand Hotel (musical)',
#  'A Grand Night for Singing',
#  'The Grand Tour (musical)',
#  'Grease (musical)',
#  'The Great Waltz',
#  'Greenwillow',
#  'Grey Gardens (musical)',
#  'Grind (musical)',
#  'Groundhog Day (musical)',
#  'Guys and Dolls',
#  'Gypsy (musical)',
#  'Hair (musical)',
#  'Hairspray (musical)',
#  'Half a Sixpence',
#  'Hallelujah, Baby!',
#  'Hamilton (musical)',
#  'Hands on a Hardbody (musical)',
#  'The Happiest Girl in the World',
#  'Happy Hunting',
#  'Happy New Year (musical)',
#  'The Happy Time (musical)',
#  'Happy Town (musical)',
#  "Harrigan 'N Hart",
#  'Hazel Flagg',
#  'Head Over Heels (musical)',
#  'Hello, Dolly! (musical)',
#  'Hellzapoppin (musical)',
#  'Henry, Sweet Henry',
#  'Her First Roman',
#  "Here's Love",
#  "Here's Where I Belong",
#  'High Button Shoes',
#  'High Fidelity (musical)',
#  'High Society (musical)',
#  'High Spirits (musical)',
#  'Higher and Higher (musical)',
#  'Hit the Deck (musical)',
#  'Hitchy-Koo',
#  'Hold Everything!',
#  'Hold On to Your Hats',
#  'Holiday Inn (musical)',
#  'Holler If Ya Hear Me (musical)',
#  'Hollywood Pinafore',
#  'Home Sweet Homer',
#  'Honeymoon in Vegas (musical)',
#  'Hooray for What!',
#  'Hot Feet',
#  'The Hot Mikado (1939 production)',
#  'Hot Spot (musical)',
#  'House of Flowers (musical)',
#  'How Now, Dow Jones',
#  'How to Succeed in Business Without Really Trying (musical)',
#  'The Human Comedy (musical)',
#  'I Can Get It for You Wholesale',
#  'I Do! I Do! (musical)',
#  'I Had a Ball',
#  'I Love My Wife',
#  'I Married an Angel',
#  'I Remember Mama (musical)',
#  "I'd Rather Be Right",
#  "I'll Say She Is",
#  'If/Then',
#  'Illya Darling',
#  'In Dahomey',
#  'In Gay New York',
#  'In the Heights',
#  'In Transit (musical)',
#  'Into the Light (musical)',
#  'Into the Woods',
#  'Irene (musical)',
#  'Irma La Douce (musical)',
#  'Is There Life After High School?',
#  "It Ain't Nothin' But the Blues",
#  'It Shoulda Been You',
#  "It's a Bird... It's a Plane... It's Superman",
#  'Jackpot (musical)',
#  'Jamaica (musical)',
#  "James Joyce's The Dead",
#  'Jane Eyre (musical)',
#  'Jekyll & Hyde (musical)',
#  "Jelly's Last Jam",
#  'Jennie (musical)',
#  "Jerome Robbins' Broadway",
#  "Jerry's Girls",
#  'Jersey Boys',
#  'Jesus Christ Superstar',
#  'Jimmy (musical)',
#  'Jimmy Shine',
#  'John Henry (musical)',
#  "John Murray Anderson's Almanac",
#  'Johnny Johnson (musical)',
#  'Joseph and the Amazing Technicolor Dreamcoat',
#  'A Joyful Noise',
#  'Jubilee (musical)',
#  'Jumbo (musical)',
#  'Juno (musical)',
#  'Kat and the Kings',
#  'Katinka (operetta)',
#  'Kean (musical)',
#  'Keep Off the Grass',
#  'Kelly (musical)',
#  'Kid Boots',
#  'The King and I',
#  'King David (musical)',
#  'King Kong (2013 musical)',
#  'King of Hearts (musical)',
#  'Kinky Boots (musical)',
#  'Kismet (musical)',
#  'Kiss Me, Kate',
#  'Kiss of the Spider Woman (musical)',
#  'Knickerbocker Holiday',
#  'A Kurt Weill Cabaret',
#  'Kwamina (musical)',
#  'La La Lucille',
#  'Lady in the Dark',
#  'Lady, Be Good (musical)',
#  'Laffing Room Only',
#  'The Last Ship (musical)',
#  'Late Nite Comic',
#  'Leader of the Pack (musical)',
#  'Leave It to Jane',
#  'Leave It to Me!',
#  'Legally Blonde (musical)',
#  'Legs Diamond (musical)',
#  'Lend an Ear',
#  'Lennon (musical)',
#  'Lestat (musical)',
#  "Let 'Em Eat Cake",
#  'Let It Ride (musical)',
#  'Let My People Come',
#  "Let's Face It!",
#  'The Lieutenant (musical)',
#  'Life Begins at 8:40',
#  'The Life (musical)',
#  'The Light in the Piazza (musical)',
#  "Li'l Abner (musical)",
#  'The Lion King (musical)',
#  'The Little Blue Devil',
#  'Little Jessie James',
#  'Little Johnny Jones',
#  'Little Me (musical)',
#  'The Little Mermaid (musical)',
#  'Little Nellie Kelly (musical)',
#  'A Little Night Music',
#  'The Little Prince and the Aviator',
#  'Little Shop of Horrors (musical)',
#  'The Little Show',
#  'Little Women (musical)',
#  'Lollipop (musical)',
#  'The Look of Love (musical)',
#  'Look to the Lilies',
#  'Lorelei (musical)',
#  'Lost in the Stars',
#  'Lost, Strayed or Stolen',
#  'Louisiana Purchase (musical)',
#  'Love Life (musical)',
#  "Love O' Mike",
#  'Lovely Ladies, Kind Gentlemen',
#  'LoveMusik',
#  'Lute Song (musical)',
#  'Lysistrata Jones',
#  'Mack and Mabel',
#  'The Madwoman of Central Park West',
#  'Magdalena: a Musical Adventure',
#  'Maggie Flynn',
#  'The Magic Show',
#  'Make a Wish (musical)',
#  'Make It Snappy',
#  'Mame (musical)',
#  'Mamma Mia!',
#  'Man of La Mancha',
#  'Man on the Moon (musical)',
#  'Marie Christine',
#  'Marinka (operetta)',
#  'Marlowe (musical)',
#  'Marriage a la Carte',
#  'Mary Jane McKane',
#  'Mary Poppins (musical)',
#  'Matilda the Musical',
#  'May Wine',
#  'Mayor (musical)',
#  'Maytime (musical)',
#  'Me and Bessie',
#  'Me and Juliet',
#  'Me and My Girl',
#  'The Me Nobody Knows',
#  'Mean Girls (musical)',
#  'Meet Me in St. Louis (musical)',
#  'Memphis (musical)',
#  'Memphis Bound',
#  'Merlin (musical)',
#  'Merrily We Roll Along (musical)',
#  'The Merry Monarch (musical)',
#  'Metro (musical)',
#  'Mexican Hayride (musical)',
#  "Michael Todd's Peep Show",
#  'The Midnight Sons',
#  'Milk and Honey (musical)',
#  'Million Dollar Quartet (musical)',
#  "Minnie's Boys",
#  'Les Misérables (musical)',
#  'Miss 1917',
#  'Miss Dolly Dollars',
#  'Miss Liberty',
#  'Miss Saigon',
#  'Mlle. Modiste',
#  'Molly (musical)',
#  'The Most Happy Fella',
#  'Motown: The Musical',
#  "Movin' Out (musical)",
#  'Mr. President (musical)',
#  'Mr. Wonderful (musical)',
#  'Music Box Revue',
#  'Music in the Air',
#  'Music Is',
#  'The Music Man',
#  'My Fair Lady',
#  'My Favorite Year (musical)',
#  'My Maryland',
#  'My One and Only (musical)',
#  'Natasha, Pierre & The Great Comet of 1812',
#  'Naughty Marietta (operetta)',
#  'Never Gonna Dance',
#  'New Faces of 1952',
#  'New Girl in Town',
#  'The New Yorkers',
#  'Newsies (musical)',
#  'Next to Normal',
#  'Nice Work If You Can Get It (musical)',
#  'Nick & Nora',
#  'The Night Boat',
#  'A Night in Spain',
#  'The Night That Made America Famous',
#  'A Night with Janis Joplin',
#  'Nine (musical)',
#  'No Strings',
#  'No, No, Nanette',
#  'Of Thee I Sing',
#  'Oh, Boy! (musical)',
#  'Oh, Captain!',
#  'Oh, Kay!',
#  'Oh, Lady! Lady!!',
#  'Oh, My Dear!',
#  'Oh! Calcutta!',
#  'Oh! Oh! Delphine',
#  'Oklahoma!',
#  'Oliver!',
#  'On a Clear Day You Can See Forever',
#  'On the Town (musical)',
#  'On the Twentieth Century',
#  'On Your Feet!',
#  'On Your Toes',
#  'Once (musical)',
#  'Once on This Island',
#  'Once Upon a Mattress',
#  "One Mo' Time (musical)",
#  'One Night Stand (musical)',
#  'One Touch of Venus',
#  'Onward Victoria',
#  'Out of This World (musical)',
#  'Over Here!',
#  'Pacific Overtures',
#  'Paint Your Wagon (musical)',
#  'The Pajama Game',
#  'Pal Joey (musical)',
#  'Panama Hattie',
#  'Panjandrum (musical)',
#  'Parade (musical)',
#  'Paramour (Cirque du Soleil)',
#  'Pardon My English',
#  'Template:Parfumerie',
#  'Paris (1928 musical)',
#  'Park Avenue (musical)',
#  'A Party with Betty Comden and Adolph Green',
#  'The Passing Show',
#  'The Passing Show of 1916',
#  'The Passing Show of 1918',
#  'Passing Strange',
#  'Passion (musical)',
#  'Peggy-Ann',
#  'The People in the Picture',
#  'Peter Pan (1954 musical)',
#  'Peter Pan (1950 musical)',
#  'The Phantom of the Opera (1986 musical)',
#  'Pickwick (musical)',
#  'The Pink Lady (musical)',
#  'Pins and Needles',
#  'Pipe Dream (musical)',
#  'Pippin (musical)',
#  'The Pirate Queen',
#  'Plain and Fancy',
#  'Platinum (musical)',
#  'Play On!',
#  'La Plume de Ma Tante',
#  'Poor Little Ritz Girl',
#  'Poppy (1923 musical)',
#  'Porgy and Bess',
#  'Portofino (musical)',
#  'Present Arms (musical)',
#  'Pretty Woman: The Musical',
#  'Prince Ananias',
#  'Prince of Broadway',
#  'Prince of Central Park (musical)',
#  'Princess Charming',
#  'Princess Flavia',
#  'The Princess Pat',
#  'Priscilla, Queen of the Desert (musical)',
#  'The Producers (musical)',
#  'The Prom (musical)',
#  'Promises, Promises (musical)',
#  'Pump Boys and Dinettes',
#  'Purlie',
#  'Putting It Together',
#  'Quilters (musical)',
#  "Rachael Lily Rosenbloom (And Don't You Ever Forget It)",
#  'Raggedy Ann (musical)',
#  'Rags (musical)',
#  'Ragtime (musical)',
#  'Raisin (musical)',
#  'The Red Mill',
#  'The Red Shoes (musical)',
#  'Red, Hot and Blue',
#  'Redhead (musical)',
#  'Rent (musical)',
#  'Revenge with Music',
#  'Rex (musical)',
#  'Right This Way',
#  'Ring of Fire (musical)',
#  'The Rink (musical)',
#  'Rio Rita (musical)',
#  'Ripples (musical)',
#  'The Roar of the Greasepaint – The Smell of the Crowd',
#  'The Robber Bridegroom (musical)',
#  'Roberta',
#  'Robinson Crusoe, Jr.',
#  "Rock 'N Roll! The First 5,000 Years",
#  'Rock of Ages (musical)',
#  'Rockabye Hamlet',
#  'The Rocky Horror Show',
#  'Romance/Romance',
#  'Rosalie (musical)',
#  'The Rothschilds (musical)',
#  'Rugantino',
#  'Runaways (musical)',
#  'Sail Away (musical)',
#  'Sally (musical)',
#  'Sarafina! (musical)',
#  'Saratoga (musical)',
#  'Saturday Night Fever (musical)',
#  'Scandalous: The Life and Trials of Aimee Semple McPherson',
#  'Say When (musical)',
#  'Say, Darling',
#  'The Scarlet Pimpernel (musical)',
#  'School of Rock (musical)',
#  'The Scottsboro Boys (musical)',
#  'Sea Legs',
#  'The Second Little Show',
#  'The Secret Garden (musical)',
#  'See America First',
#  'Seesaw (musical)',
#  'The Serenade',
#  'Set to Music',
#  'Seussical',
#  'Seven Brides for Seven Brothers (musical)',
#  'Seventeen (musical)',
#  'Shangri-La (musical)',
#  'She Loves Me',
#  'Shenandoah (musical)',
#  'Sherry!',
#  'Shinbone Alley',
#  'Shōgun: The Musical',
#  'Show Boat',
#  'Show Girl (1929 musical)',
#  'Show Me Where the Good Times Are',
#  'Shrek The Musical',
#  'Shuffle Along',
#  'Shuffle Along, or, the Making of the Musical Sensation of 1921 and All That Followed',
#  'Side by Side by Sondheim',
#  'Side Show',
#  'Silk Stockings',
#  'Simple Simon (musical)',
#  'Simply Heavenly',
#  'Sinbad (musical)',
#  "Singin' in the Rain (musical)",
#  'The Siren (musical)',
#  'Sister Act (musical)',
#  'Skyscraper (musical)',
#  'Smile (musical)',
#  'Smiling Faces',
#  "Smokey Joe's Cafe",
#  'So Long, 174th Street',
#  'Something for the Boys',
#  'Something More!',
#  'Something Rotten!',
#  "Something's Afoot",
#  'Sometime (musical)',
#  'Sondheim on Sondheim',
#  'Song and Dance',
#  'Song of Norway',
#  'Song of the Flame',
#  "Sons o' Fun",
#  'Soon (musical)',
#  'Sophisticated Ladies',
#  'Soul Doctor',
#  'The Sound of Music',
#  'South Pacific (musical)',
#  'Spamalot',
#  'Spider-Man: Turn Off the Dark',
#  'SpongeBob SquarePants (musical)',
#  'Spring Awakening (musical)',
#  'St. Louis Woman',
#  'Star and Garter',
#  'Starlight Express',
#  'Starmites',
#  'State Fair (musical)',
#  'Steel Pier (musical)',
#  'Stepping Stones (musical)',
#  'Stop the World – I Want to Get Off',
#  'Stop! Look! Listen!',
#  'The Story of My Life (musical)',
#  'La Strada (musical)',
#  'Street Scene (opera)',
#  'The Streets of Paris',
#  'Strike Up the Band (musical)',
#  'Stubborn Cinderella',
#  'Subways Are for Sleeping',
#  'Sugar (musical)',
#  'Sugar Babies (musical)',
#  'Summer: The Donna Summer Musical',
#  'Sunday in the Park with George',
#  'Sunny (musical)',
#  'Sunset Boulevard (musical)',
#  'Sweeney Todd: The Demon Barber of Fleet Street',
#  'Sweet Adeline (musical)',
#  'Sweet and Low (musical)',
#  'Sweet Charity',
#  'Sweet Smell of Success (musical)',
#  'Sweethearts (musical)',
#  'Swing!',
#  'Swinging on a Star (musical)',
#  'Taboo (musical)',
#  'Take a Chance (musical)',
#  'Take Me Along',
#  'A Tale of Two Cities (musical)',
#  'Tambourines to Glory',
#  'Tangerine (musical)',
#  'The Tap Dance Kid',
#  'Tarzan (musical)',
#  'Teddy & Alice',
#  'The Telephone Girl',
#  'Tell Me on a Sunday',
#  'Tenderloin (musical)',
#  'The Charlatan (operetta)',
#  "They're Playing Our Song",
#  'This Year of Grace',
#  'Thoroughly Modern Millie (musical)',
#  'Thou Shalt Not (musical)',
#  'Three Cheers',
#  'The Three Musketeers (musical)',
#  'Three Wishes for Jamie',
#  'The Threepenny Opera',
#  'Thumbs Up! (musical)',
#  'Tickle Me (play)',
#  'Timbuktu!',
#  'A Time for Singing',
#  "The Times They Are a-Changin' (musical)",
#  'Tintypes',
#  'Tip-Toes',
#  'Titanic (musical)',
#  'Title of show',
#  "To-Night's the Night (musical)",
#  'Too Many Girls (musical)',
#  'Top Banana (musical)',
#  'Tovarich (musical)',
#  'Town Topics (musical)',
#  'Treasure Girl',
#  'A Tree Grows in Brooklyn (musical)',
#  'A Trip to Chinatown',
#  'Triumph of Love (musical)',
#  'Tuck Everlasting (musical)',
#  'Two by Two (musical)',
#  'Two for the Show (musical)',
#  'Two Gentlemen of Verona (musical)',
#  'Two Little Girls in Blue',
#  'Two on the Aisle',
#  "Two's Company (musical)",
#  'The Unsinkable Molly Brown (musical)',
#  'Up in Central Park',
#  "Uptown... It's Hot!",
#  'Urban Cowboy (musical)',
#  'Urinetown',
#  'The Utter Glory of Morrissey Hall',
#  'The Vagabond King',
#  'The Vamp',
#  'Vera Violetta',
#  'Very Good Eddie',
#  'Very Warm for May',
#  'Via Galactica',
#  'Victor/Victoria (musical)',
#  'Wait a Minim!',
#  'Waitress (musical)',
#  'Wake Up and Dream',
#  'Walk a Little Faster',
#  'Walking Happy',
#  'War Paint (musical)',
#  'Watch Your Step (musical)',
#  'The Wedding Singer (musical)',
#  'Welcome to the Club (musical)',
#  'The Well of Romance',
#  'West Side Story',
#  'What Makes Sammy Run? (musical)',
#  "What's Up? (musical)",
#  "Where's Charley?",
#  'The Whirl of New York',
#  'The Whirl of Society',
#  'White Christmas (musical)',
#  'White Horse Inn (Broadway version)',
#  'The White Horse Inn',
#  "The Who's Tommy",
#  'Whoop-Dee-Doo',
#  'Whoop-Up',
#  'Whoopee!',
#  'Wicked (musical)',
#  'The Widow Jones',
#  'The Wild Party (LaChiusa musical)',
#  'Wildcat (musical)',
#  'Wildflower (musical)',
#  'The Will Rogers Follies',
#  'Wish You Were Here (musical)',
#  'The Wiz',
#  'The Wizard of the Nile',
#  'The Woman in White (musical)',
#  'Woman of the Year (musical)',
#  'Women on the Verge of a Nervous Breakdown (musical)',
#  'A Wonderful Life (musical)',
#  'Wonderful Town',
#  'Working (musical)',
#  'Xanadu (musical)',
#  'A Year with Frog and Toad',
#  'Yip Yip Yaphank',
#  'You Never Know (musical)',
#  'You Said It',
#  "You're a Good Man, Charlie Brown",
#  'Young Frankenstein (musical)',
#  'Your Arms Too Short to Box with God',
#  'Ziegfeld Follies',
#  'Ziegfeld Follies of 1936',
#  'Zorba (musical)',
#  'The Zulu and the Zayda',
#  'Category:Cats (musical)',
#  'Category:Dreamgirls',
#  'Category:Hamilton (musical)',
#  'Category:Mame',
#  'Category:Oklahoma!',
#  'Category:The Phantom of the Opera (1986 musical)',
#  'Category:The Sound of Music',
#  'Category:Warner Bros. Theatrical',
#  'Category:Ziegfeld Follies']

# %% [markdown]
# ## Download text data for each show and put it in a folder on Desktop ##

# %% [markdown]
# ### Before doing the step below, I had to change the names of shows in the original broadway data set to get the correct Wikipedia summeries ###
#
# 1. The shows I manusally changed were:
# 2. Beautiful-> Beautiful: The Carol King Musical
# 3. Cabaret'14 -> Cabaret (musical)
# 4. Fela! '14 -> Fela! (musical)
# 5. Hamilton -> Hamilton (musical)
# 6. The People In the Picture->The People in the Picture
# 7. Spring Awakening 2014 -> Spring Awakening

# %%
#show_list

# %%
#Making a list of the summaries of all 113 shows
reviews=[]
show_list2=[]
for a in show_list:
    if '(musical)' in a: #if already states in name that it is musical, add
        show_list2.append(a)
        w=wikipedia.page(a)
        reviews.append(w.summary)
    elif 'Musical' in a: # "  " ^
        show_list2.append(a)
        w=wikipedia.page(a)
        reviews.append(w.summary)
    elif '(musical)' not in a: #special case show...name in data set not akin to what Wikipedia needs for search
        if a == 'Paramour':
            show_list2.append(a)
            w=wikipedia.page(a +'(Cirque du Soleil)')
            reviews.append(w.summary)
        if a in ['Fela!','Godspell', 'The People in the Picture']: 
            show_list2.append(a)#Shows Wikipedia doesn't identitfy with 'musical' in the name
            w=wikipedia.page(a)
            reviews.append(w.summary)
        if a not in ['Fela!','Godspell','Paramour','The People in the Picture']:  
            show_list2.append(a)
            w=wikipedia.page(a +'(musical)') #make sure shows with book, movie, etc. names pull only Wikipedia's musical article
            reviews.append(w.summary)
# Out:
# ---------------------------------------------------------------------------
# PageError                                 Traceback (most recent call last)
# <ipython-input-44-7a9f0d269bc4> in <module>()
#      22         if a not in ['Fela!','Godspell','Paramour','The People in the Picture']:
#      23             show_list2.append(a)
# ---> 24             w=wikipedia.page(a +'(musical)') #make sure shows with book, movie, etc. names pull only Wikipedia's musical article
#      25             reviews.append(w.summary)
#      26
#
# /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages/wikipedia/wikipedia.py in page(title, pageid, auto_suggest, redirect, preload)
#     274         # if there is no suggestion or search results, the page doesn't exist
#     275         raise PageError(title)
# --> 276     return WikipediaPage(title, redirect=redirect, preload=preload)
#     277   elif pageid is not None:
#     278     return WikipediaPage(pageid=pageid, preload=preload)
#
# /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages/wikipedia/wikipedia.py in __init__(self, title, pageid, redirect, preload, original_title)
#     297       raise ValueError("Either a title or a pageid must be specified")
#     298
# --> 299     self.__load(redirect=redirect, preload=preload)
#     300
#     301     if preload:
#
# /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages/wikipedia/wikipedia.py in __load(self, redirect, preload)
#     343     if 'missing' in page:
#     344       if hasattr(self, 'title'):
# --> 345         raise PageError(self.title)
#     346       else:
#     347         raise PageError(pageid=self.pageid)
#
# PageError: Page id "greater 07 musical" does not match any pages. Try another id!

# %%
#Making sure all shows have reviews
len(reviews)   
list(set(show_list) - set(show_list2))

# %%
os.chdir ('/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries')

#Making text documeents for each of the reviews
for i,r in enumerate(reviews):
    file=open( 'show' + str(i) + '.txt', 'w')
    file.write(r)

# %% [markdown]
# ## Beginning to tokenize ##
# ### First by sentences ###

# %%
#Sentences
from nltk import sent_tokenize
directory='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries'
def sents(directory): 
    
    """
    Uses the built in sentence tokenizer to extract sentences from the
    paragraphs. Note that this method uses BeautifulSoup to parse HTML.        """     
    for file in os.listdir(directory): 
        with open(os.path.join(directory, file)) as f:
            #for sentence in sent_tokenize(f):                
            print(f)
sents(directory)
# Out:
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/.DS_Store' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/A Christmas Story.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name="/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/A Gentleman'S Guide To Love And Murder.txt" mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/A Little Night Music.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/A Night With Janis Joplin.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/After Midnight.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Aladdin.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Allegiance.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Amazing Grace.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/American Idiot.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/American Psycho.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/An American In Paris.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name="/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Annie '12.txt" mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name="/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Anything Goes '11.txt" mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name="/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Baby It'S You!.txt" mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Beautiful: The Carole King Musical.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Big Fish.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Billy Elliot: The Musical.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Bloody Bloody Andrew Jackson.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Bonnie And Clyde.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Bright Star.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Bring It On The Musical.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Bullets Over Broadway.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Cabaret (musical).txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Catch Me If You Can.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Cats 2016.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Chaplin.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Chicago.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Cinderella.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Dames At Sea.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Disaster!.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Doctor Zhivago.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name="/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Elf '12.txt" mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Elf.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Evita.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Fela!.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Fiddler On The Roof 2015.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Finding Neverland.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/First Date.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name="/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Follies '11.txt" mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Fun Home.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Ghost.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Gigi.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Godspell.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name="/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Hair '11.txt" mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Hamilton (musical).txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Hands On A Hardbody.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Hedwig And The Angry Inch.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Holler If Ya Hear Me.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/Honeymoon In Vegas.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name="/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/How To Succeed In Business Without Really Trying '11.txt" mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show100.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show101.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show102.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show103.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show104.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show105.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show106.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show107.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show108.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show109.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show110.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show111.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show112.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show40.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show41.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show42.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show43.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show44.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show45.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show46.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show47.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show48.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show49.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show50.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show51.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show52.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show53.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show54.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show55.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show56.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show57.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show58.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show59.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show60.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show61.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show62.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show63.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show64.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show65.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show66.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show67.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show68.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show69.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show70.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show71.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show72.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show73.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show74.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show75.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show76.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show77.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show78.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show79.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show80.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show81.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show82.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show83.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show84.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show85.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show86.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show87.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show88.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show89.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show90.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show91.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show92.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show93.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show94.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show95.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show96.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show97.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show98.txt' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries/show99.txt' mode='r' encoding='UTF-8'>

# %%
#another example of tokenization from chapter 4
import nltk
import string

def tokenize(text):
    stem = nltk.stem.SnowballStemmer('english')
    text = text.lower()

    for token in nltk.word_tokenize(text):
        if token in string.punctuation: continue
        yield stem.stem(token)

corpus = [
    "The elephant sneezed at the sight of potatoes.",
    "Bats can see via echolocation. See the bat sight sneeze!",
    "Wondering, she opened the door to the studio.",
]

# %%
#within sentences, words

# %% [markdown]
# ### Vectorization ##

# %%
#one-hot encoding, better for small documents because of non-repeatability 
def vectorize(doc):
    return {
        token: True
        for token in doc
    }

vectors = map(vectorize, corpus)

# %%
#TF-IDF, using the TextCollection class
#Probably best to use
from nltk.text import TextCollection

def vectorize(corpus):
    corpus = [tokenize(doc) for doc in corpus]
    texts  = TextCollection(corpus)

    for doc in corpus:
        yield {
            term: texts.tf_idf(term, doc)
            for term in doc
        }

# %% [markdown]
# ## DO some type of normalization ##
# lemmatization
# stemming
# removing words that occur < 10% of the time
# removing stop words

# %% [markdown]
# ## Initializing the Model ##

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer

def identity(words):
    return words

def create_pipeline(estimator, reduction=False):

    steps = [
        ('normalize', TextNormalizer()),
        ('vectorize', TfidfVectorizer(
            tokenizer=identity, preprocessor=None, lowercase=False
        ))
    ]

    if reduction:
        steps.append((
            'reduction', TruncatedSVD(n_components=10000)
        ))

    # Add the estimator
    steps.append(('classifier', estimator))
    return Pipeline(steps)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier

models = []
for form in (LogisticRegression, MultinomialNB, SGDClassifier):
    models.append(create_pipeline(form(), True))
    models.append(create_pipeline(form(), False))

# %%
for model in models:
    model.fit(train_docs, train_labels)

# %% [markdown]
# ## Set up for splits ##

# %%
#Assessing what happens if we use TextBlob, a pretrained sentiment classifier...for reference
summary_sent=[]
for r in reviews:
    blob = TextBlob(r) #grabs the text in each headline
    sent=blob.sentiment.polarity #polarity between (0-1) of the
    summary_sent.append(sent)
summary_sent

summary_sentimentality=pd.DataFrame({'Name':show_list ,'Sentimentality':summary_sent}) #Makes dataframe of 

summary_sentimentality.sort_values(by=['Sentimentality'])
# Out:
#                                    Name  Sentimentality
# 17         Bloody Bloody Andrew Jackson       -0.320000
# 4                        After Midnight       -0.104167
# 20              Bring It On The Musical       -0.071441
# 45                  Hands On A Hardbody       -0.066667
# 37                           First Date       -0.062500
# 15                             Big Fish       -0.042857
# 5                               Aladdin       -0.022203
# 6                            Allegiance       -0.020833
# 10                 An American In Paris       -0.012500
# 47                 Holler If Ya Hear Me        0.000000
# 48                   Honeymoon In Vegas        0.000000
# 52                  It Shoulda Been You        0.000000
# 13                       Baby It'S You!        0.000000
# 103           The People in the Picture        0.000000
# 73             On The Twentieth Century        0.006061
# 85                           Scandalous        0.006061
# 106                    Tuck Everlasting        0.007273
# 40                                Ghost        0.012500
# 18                     Bonnie And Clyde        0.017980
# 25                              Chaplin        0.022727
# 65               Million Dollar Quartet        0.025000
# 3             A Night With Janis Joplin        0.031818
# 31                                  Elf        0.034091
# 32                              Elf '12        0.034091
# 26                              Chicago        0.039333
# 93         Spider-Man Turn Off The Dark        0.042788
# 87                    She Loves Me 2016        0.043333
# 30                       Doctor Zhivago        0.045455
# 36                    Finding Neverland        0.045833
# 50                              If/Then        0.048052
# ..                                  ...             ...
# 98                The Color Purple 2015        0.177500
# 69                       Next To Normal        0.178808
# 44                   Hamilton (musical)        0.180481
# 80        Priscilla Queen Of The Desert        0.180500
# 54                          Jersey Boys        0.181960
# 104            The Phantom Of The Opera        0.182168
# 107                              Violet        0.183333
# 92                          Soul Doctor        0.184848
# 34                                Fela!        0.190000
# 35             Fiddler On The Roof 2015        0.191304
# 39                             Fun Home        0.198131
# 76                                 Once        0.198478
# 63                              Matilda        0.200879
# 109                     West Side Story        0.202492
# 96                   The Book Of Mormon        0.206261
# 99                  The King And I 2015        0.209654
# 11                            Annie '12        0.229722
# 28                         Dames At Sea        0.231201
# 19                          Bright Star        0.240000
# 23                  Catch Me If You Can        0.250000
# 102      The Mystery Of Edwin Drood '12        0.264520
# 97        The Bridges Of Madison County        0.271875
# 14   Beautiful: The Carole King Musical        0.277083
# 81                   Promises, Promises        0.277778
# 62                         Mary Poppins        0.278750
# 91                    Something Rotten!        0.284524
# 57               La Cage Aux Folles '10        0.330180
# 100                       The Last Ship        0.372222
# 70          Nice Work If You Can Get It        0.400000
# 51                       In The Heights        0.413961
#
# [113 rows x 2 columns]

# %% [markdown]
# ## Analysis ##

# %% [markdown]
# ###  Distribution of Sentiment Scores ###

# %%
#Exporting sentimentalities as a csv file
pd.DataFrame.to_csv(summary_sentimentality,'summary_sentimentality.csv')

# %%
#Distribution of Wikipedia Sentimentalities
plot=summary_sentimentality['Sentimentality'].hist()
plot.set_xlabel("Sentimentality")
plot.set_ylabel("Frequency")
plot.set_title("Distribution of Wikipedia Summary Sentimentalities")

plt.show()

# %%
summary_sentimentality.head(10) #lowest sentimentalities
summary_sentimentality.tail(10) #top sentimentalities

#Number of weeks each show was on Broadway
weeks=pd.DataFrame(Google_Parameters['Name'].value_counts())
weeks=weeks.reset_index()
weeks=weeks.rename(index=str, columns={"index": "Name1", "Name": "Weeks"})
weeks=weeks.sort_values(by=['Name1'])
weeks=weeks.reset_index()

#Merging sentimentality and weeks on Broadway 
Wikipedia = pd.concat([weeks, summary_sentimentality], axis=1)
Wikipedia.drop(['index','Name1'],axis=1) #Clean
Wikipedia = Wikipedia[['Name', 'Weeks', 'Sentimentality']]

pd.DataFrame.to_csv(Wikipedia,'Wikipedia_Data.csv')

# %% [markdown]
# ### Weeks v. Sentimentality ###

# %%
#log transform weeks 
Wikipedia['Weeks'] = np.log(Wikipedia['Weeks'])
Wikipedia['Weeks'].hist()
plt.show()

# %%
#Scatter plot
Wikipedia.plot.scatter(x='Weeks', y='Sentimentality', rot=0)
plt.show()

# %% [markdown]
# ## Insert a question of interest here ###
