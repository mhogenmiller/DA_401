# %%
#Adding Packages
import requests as rq
import json
import os
import wikipedia
from urllib.request import urlopen
import pandas as pd
from bs4 import BeautifulSoup
from textblob import TextBlob
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
from nltk import wordpunct_tokenize
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
# Out:
# /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
#How to get a full WIkipedia article using json ##
url = "https://en.wikipedia.org/w/api.php?format=json&action=query&titles=Hamilton&prop=revisions&rvprop=content"
data = rq.get(url).json()
bfile = open('Hamilton.txt', 'w+')
json.dump(data, bfile)
bfile.close()

# %% [markdown]
# ## Referencing List of Broadway Shows Since 2010, CORGI ##

# %%
Broadway_Original = pd.read_csv('/Users/morganhogenmiller/Desktop/DA 401/Data sets/broadway(corgi) copy.csv') #Read in CORGI data set

# %%
Google_Parameters= Broadway_Original[['Name','Year','Month','Day','Type']] #Reduce data set to variables to input into GT

#Filter to shows after 2007 only
Google_Parameters=Google_Parameters.loc[Google_Parameters['Year']>2007] 
Google_Parameters=Google_Parameters.loc[Google_Parameters['Type']=='Musical']

# %%
#Provides a list of shows in form needed for function 
show_list=list(Google_Parameters.Name.unique()) 
show_list.sort() #in alphabetical order
show_list.remove('Les Misrables 2006')

# %% [markdown]
# ## Counting number of articles within Wikipedia category for Broadway musicals##

# %%
#To clean, make something that says if it begins with Category, take it out
def categories(category):
    """This function takes a Wikipedia category as an input and outputs the number of Wikipedia
    articles that exist in that category."""
    count = "0"
    articles = list()

    # Loop through each musical and update count each time
    while True:
        url = "https://en.wikipedia.org/w/api.php?format=json&action=query&list=categorymembers&cmtitle=Category:"+category+"&cmlimit=500&prop=revisions&rvprop=content&cmcontinue="+ count
        data = rq.get(url).json()
        articles.extend(data['query']['categorymembers'])
        try:
            count = data['continue']['cmcontinue']
        except:
            break

    # Get the heroes and villains and ambiguous's names from the data
    articles = [x['title'] for x in articles]

    return("Number of articles in the "+ category + " category: "+ str(len(articles)), articles)

# %%
results=categories('Broadway_musicals')
articles=results[1] # creating an object for the list of musical titles
#categories('Tony_Award_Winning_musicals')
len(articles)
# Out:
# 884

# %% [markdown]
# ## Download text data for each show ##

# %% [markdown]
# ### Before doing the step below, I had to change the names of shows in the original broadway data set to get the correct Wikipedia summeries ###
#
# 1. The shows I manusally changed were:
# 2. Beautiful-> Beautiful: The Carol King Musical
# 3. Cabaret'14 -> Cabaret (musical)
# 4. Fela! '14 -> Fela! (musical)
# 5. Hamilton -> Hamilton (musical)
# 6. The People In the Picture->The People in the Picture
# 7. Spring Awakening 2014 -> Spring Awakening
# 8. Grease 07 -> Grease (This is okay to do because the other production of Grease is before the 2007 cut-off)
# 9. Les Miserables 2006 deleted

# %%
show_list
# Out:
# ['13',
#  '9 To 5',
#  'A Catered Affair',
#  "A Chorus Line '06",
#  'A Christmas Story',
#  "A Gentleman'S Guide To Love And Murder",
#  'A Little Night Music',
#  'A Night With Janis Joplin',
#  'A Tale Of Two Cities',
#  'After Midnight',
#  'Aladdin',
#  'All About Me',
#  'Allegiance',
#  'Amazing Grace',
#  'American Idiot',
#  'American Psycho',
#  'An American In Paris',
#  "Annie '12",
#  "Anything Goes '11",
#  'Avenue Q',
#  "Baby It'S You!",
#  'Beautiful: The Carole King Musical',
#  'Big Fish',
#  'Billy Elliot: The Musical',
#  'Bloody Bloody Andrew Jackson',
#  'Bonnie And Clyde',
#  'Bright Star',
#  'Bring It On The Musical',
#  'Bullets Over Broadway',
#  'Burn The Floor',
#  'Bye Bye Birdie',
#  'Cabaret (musical)',
#  'Catch Me If You Can',
#  'Cats 2016',
#  'Chaplin',
#  'Chicago',
#  'Cinderella',
#  'Come Fly Away',
#  'Cry Baby',
#  'Curtains',
#  'Dames At Sea',
#  'Disaster!',
#  'Doctor Zhivago',
#  "Dr. Seuss' How The Grinch Stole Christmas! 07",
#  'Elf',
#  "Elf '12",
#  'Everyday Rapture',
#  'Evita',
#  'Fela!',
#  'Fiddler On The Roof 2015',
#  'Finding Neverland',
#  "Finian'S Rainbow",
#  'First Date',
#  "Follies '11",
#  'Fun Home',
#  'Ghost',
#  'Gigi',
#  'Glory Days',
#  'Godspell',
#  'Grease',
#  "Guys And Dolls '09",
#  "Gypsy '08",
#  'Hair',
#  "Hair '11",
#  'Hairspray',
#  'Hamilton (musical)',
#  'Hands On A Hardbody',
#  'Hedwig And The Angry Inch',
#  'Holler If Ya Hear Me',
#  'Honeymoon In Vegas',
#  "How To Succeed In Business Without Really Trying '11",
#  'If/Then',
#  'In The Heights',
#  "Irving Berlin'S White Christmas",
#  "Irving Berlin'S White Christmas '09",
#  'It Shoulda Been You',
#  "Jekyll & Hyde '13",
#  'Jersey Boys',
#  "Jesus Christ Superstar '12",
#  'Kinky Boots',
#  "La Cage Aux Folles '10",
#  'Leap Of Faith',
#  'Legally Blonde',
#  'Les Miserables (musical)',
#  'Lysistrata Jones',
#  'Mamma Mia!',
#  'Mary Poppins',
#  'Matilda',
#  'Memphis',
#  'Million Dollar Quartet',
#  "Monty Python'S Spamalot",
#  'Motown The Musical',
#  'Motown The Musical 2016',
#  'Newsies',
#  'Next To Normal',
#  'Nice Work If You Can Get It',
#  'On A Clear Day You Can See Forever',
#  'On The Town',
#  'On The Twentieth Century',
#  'On Your Feet!',
#  'On the Town (musical)',
#  'Once',
#  'Pal Joey',
#  'Paramour',
#  'Passing Strange',
#  'Pippin',
#  "Porgy And Bess '11",
#  'Priscilla Queen Of The Desert',
#  'Promises, Promises',
#  "Ragtime '09",
#  'Rain: A Tribute To The Beatles On Broadway',
#  'Rent',
#  'Rock Of Ages',
#  'Rocky',
#  'Scandalous',
#  'School Of Rock',
#  'She Loves Me 2016',
#  'Shrek The Musical',
#  'Shuffle Along',
#  'Side Show 2014',
#  'Sister Act',
#  'Something Rotten!',
#  'Sondheim On Sondheim',
#  'Soul Doctor',
#  'South Pacific',
#  'Spider-Man Turn Off The Dark',
#  'Spring Awakening',
#  "Sunday In The Park With George '08",
#  'The 25Th Annual Putnam County Spelling Bee',
#  'The Addams Family',
#  'The Book Of Mormon',
#  'The Bridges Of Madison County',
#  'The Color Purple',
#  'The Color Purple 2015',
#  'The King And I 2015',
#  'The Last Ship',
#  'The Lion King',
#  'The Little Mermaid',
#  "The Mystery Of Edwin Drood '12",
#  'The People in the Picture',
#  'The Phantom Of The Opera',
#  'The Scottsboro Boys',
#  'The Story Of My Life',
#  'The Visit 2015',
#  'Title Of Show',
#  'Tuck Everlasting',
#  'Violet',
#  'Waitress',
#  'West Side Story',
#  'Wicked',
#  'Women On The Verge Of A Nervous Breakdown',
#  'Wonderland',
#  'Xanadu',
#  'Young Frankenstein']

# %% [markdown]
# Some shwos had to be deleted from those that were manually categorized when it became evident that the Wikipedia synopsis was either:
# 1. Not about the musical, but a book or movie of the same name
# 2. About the director of the musical, not the musical itself
# 3. Repetitive ex. Les Miserables and Les Miserables 2006
# 4. Not about a show that made it to the main Broadway stage (this only happened with one show)
#
# The total number of shows that

# %%
#Making a pandas df with reviews and their scores
selfscores=pd.read_csv('/Users/morganhogenmiller/Desktop/DA 401/Data sets/Self_Scores_Wikipedia150.csv') #import csv with shows and self-scored catefories
name=list(selfscores['Name']) #shows in self score
score=list(selfscores['Selfscore'])

# %%
#Making a list of show synopses
reviews=[]
show_list2=[]
for a in name:
    if '(musical)' in a: #if already states in name that it is musical, add
        show_list2.append(a)
        w=wikipedia.page(a)
        reviews.append(w.summary)
    elif 'Musical' in a: # "  " ^
        show_list2.append(a)
        w=wikipedia.page(a)
        reviews.append(w.summary)
    elif '(musical)' not in a: #special case show...name in data set not akin to what Wikipedia needs for search
        if a == 'Paramour':
            show_list2.append(a)
            w=wikipedia.page(a +'(Cirque du Soleil)')
            reviews.append(w.summary)
        if a in ['Fela!','Godspell', 'The People in the Picture']: 
            show_list2.append(a)#Shows Wikipedia doesn't identitfy with 'musical' in the name
            w=wikipedia.page(a)
            reviews.append(w.summary)
        if a not in ['Fela!','Godspell','Paramour','The People in the Picture']:  
            show_list2.append(a)
            w=wikipedia.page(a +'(musical)') #make sure shows with book, movie, etc. names pull only Wikipedia's musical article
            reviews.append(w.summary)

# %%
#Exporting Synopses to a folder on desktop so that they can be scored
#os.chdir ('/Users/morganhogenmiller/Desktop/GitHub/DA_401/WikiSummaries')

#Making text documeents for each of the reviews
#for i,r in enumerate(reviews):
    #file=open( 'show' + str(i) + '.txt', 'w')
    #file.write(r)

# %%
#Creating Pandas DataFrame with each show, its synopsis, and self-scored category
synscore=pd.DataFrame({'Synopsis':reviews,'Show':name, 'Category':score})
pd.DataFrame.to_csv(synscore,'Self_Scores_137.csv')
names=pd.DataFrame({'Show':name})
pd.DataFrame.to_csv(names,'Final_Musicals.csv')

# %% [markdown]
# ## Tokenize the above synopses using the TD-IDF method ##

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=3, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(synscore.Synopsis).toarray()
labels = synscore.Category
tdidfarray=pd.DataFrame(features)
# Out:
# /Users/morganhogenmiller/anaconda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1059: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
##See what words are most popular with what categories...Do this after build model because important, but not as important 
from sklearn.feature_selection import chi2
import numpy as np
N = 2
for Product, category_id in sorted(category_to_id.items()):
    features_chi2 = chi2(features, labels == category_id)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    print("# '{}':".format(Product))
    print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
    print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))

# %% [markdown]
# ## STEP 1: Preprocessing ##

# %%
#Removing stop words
stop_words = set(stopwords.words('english'))
reviews_nonstop=[]
for r in reviews:
    r2=[]
    for word in r.split(' '):
        word=word.lower()
        if word not in stop_words:
            r2.append(word)
    reviews_nonstop.append(r2)
reviews_nonstop
# Out:
# [['13',
#   'original',
#   'musical',
#   'music',
#   'lyrics',
#   'jason',
#   'robert',
#   'brown',
#   'book',
#   'dan',
#   'elish',
#   'robert',
#   'horn.\nfollowing',
#   'move',
#   'new',
#   'york',
#   'city',
#   'small-town',
#   'indiana,',
#   'young',
#   'evan',
#   'goldman',
#   'grapples',
#   "parents'",
#   'divorce,',
#   'prepares',
#   'impending',
#   'bar',
#   'mitzvah,',
#   'navigates',
#   'complicated',
#   'social',
#   'circles',
#   'new',
#   'school.',
#   '13',
#   'broadway',
#   'musical',
#   'ever',
#   'cast',
#   'band',
#   'entirely',
#   'made',
#   'teenagers.',
#   'originally',
#   'began',
#   'previews',
#   'september',
#   '16,',
#   '2008',
#   'officially',
#   'opened',
#   'october',
#   '5,',
#   '2008',
#   'bernard',
#   'b.',
#   'jacobs',
#   'theatre.\nthe',
#   'broadway',
#   'production',
#   'closed',
#   'january',
#   '4,',
#   '2009',
#   'total',
#   '105',
#   'performances.',
#   'show',
#   'directed',
#   'jeremy',
#   'sams',
#   'starred',
#   'graham',
#   'phillips',
#   'evan',
#   'goldman',
#   'allie',
#   'trimm',
#   'patrice.',
#   'also',
#   'starred',
#   'corey',
#   'snide',
#   'evan',
#   'matinee',
#   'performances,',
#   'aaron',
#   'simon',
#   'gross',
#   'archie',
#   'walker,',
#   'eric',
#   'nelsen',
#   'brett',
#   'samson,',
#   'delaney',
#   'moro',
#   'kendra.',
#   '2008',
#   'broadway',
#   'production',
#   'notable',
#   'professional',
#   'debuts',
#   'ariana',
#   'grande',
#   'elizabeth',
#   'gillies',
#   'would',
#   'later',
#   'go',
#   'star',
#   'together',
#   'nickelodeon',
#   'television',
#   'series',
#   'victorious.'],
#  ['9',
#   '5:',
#   'musical',
#   'musical',
#   'based',
#   '1980',
#   'movie',
#   'name,',
#   'music',
#   'lyrics',
#   'dolly',
#   'parton.',
#   'features',
#   'book',
#   'patricia',
#   'resnick,',
#   'based',
#   'screenplay',
#   'resnick',
#   'colin',
#   'higgins.',
#   'musical',
#   'premiered',
#   'los',
#   'angeles',
#   'september',
#   '2008,',
#   'opened',
#   'broadway',
#   'april',
#   '2009.',
#   'received',
#   '15',
#   'drama',
#   'desk',
#   'award',
#   'nominations,',
#   'received',
#   'production',
#   'single',
#   'year,',
#   'well',
#   'four',
#   'tony',
#   'awards',
#   'nominations.',
#   'broadway',
#   'production',
#   'however',
#   'short-lived,',
#   'closing',
#   'september',
#   '2009.',
#   'national',
#   'tour',
#   'us',
#   'launched',
#   '2010,',
#   'followed',
#   'uk',
#   'premiere',
#   '2012.',
#   'opened',
#   'west',
#   'end',
#   'february',
#   '2019.'],
#  ['catered',
#   'affair',
#   '(1956),',
#   'also',
#   'known',
#   'wedding',
#   'party,',
#   'family',
#   'drama',
#   'film',
#   'made',
#   'metro-goldwyn-mayer.',
#   'directed',
#   'richard',
#   'brooks',
#   'produced',
#   'sam',
#   'zimbalist',
#   'screenplay',
#   'gore',
#   'vidal,',
#   'based',
#   'television',
#   'play',
#   'paddy',
#   'chayefsky.',
#   'film',
#   'score',
#   'andré',
#   'previn',
#   'cinematography',
#   'john',
#   'alton.\nthe',
#   'film',
#   'stars',
#   'bette',
#   'davis,',
#   'ernest',
#   'borgnine,',
#   'debbie',
#   'reynolds,',
#   'barry',
#   'fitzgerald',
#   'rod',
#   'taylor.',
#   "taylor's",
#   'first',
#   'film',
#   'mgm',
#   'signed',
#   'studio',
#   'long-term',
#   'contract.'],
#  ['chorus',
#   'line',
#   'concept',
#   'musical',
#   'music',
#   'marvin',
#   'hamlisch,',
#   'lyrics',
#   'edward',
#   'kleban',
#   'book',
#   'james',
#   'kirkwood',
#   'jr.',
#   'nicholas',
#   'dante.',
#   'centered',
#   'seventeen',
#   'broadway',
#   'dancers',
#   'auditioning',
#   'spots',
#   'chorus',
#   'line,',
#   'musical',
#   'set',
#   'bare',
#   'stage',
#   'broadway',
#   'theatre',
#   'audition',
#   'musical.',
#   'chorus',
#   'line',
#   'provides',
#   'glimpse',
#   'personalities',
#   'performers',
#   'choreographer',
#   'describe',
#   'events',
#   'shaped',
#   'lives',
#   'decisions',
#   'become',
#   'dancers.\nfollowing',
#   'several',
#   'workshops',
#   'off-broadway',
#   'production,',
#   'chorus',
#   'line',
#   'opened',
#   'shubert',
#   'theatre',
#   'broadway',
#   'july',
#   '25,',
#   '1975,',
#   'directed',
#   'michael',
#   'bennett',
#   'co-choreographed',
#   'bennett',
#   'bob',
#   'avian.',
#   'unprecedented',
#   'box',
#   'office',
#   'critical',
#   'hit,',
#   'musical',
#   'received',
#   'twelve',
#   'tony',
#   'award',
#   'nominations',
#   'nine,',
#   'addition',
#   '1976',
#   'pulitzer',
#   'prize',
#   'drama.\nthe',
#   'original',
#   'broadway',
#   'production',
#   'ran',
#   '6,137',
#   'performances,',
#   'becoming',
#   'longest-running',
#   'production',
#   'broadway',
#   'history',
#   'surpassed',
#   'cats',
#   '1997,',
#   'longest-running',
#   'broadway',
#   'musical',
#   'originally',
#   'produced',
#   'us,',
#   'surpassed',
#   '2011',
#   'chicago.',
#   'remains',
#   'seventh',
#   'longest-running',
#   'broadway',
#   'show',
#   'ever.',
#   'chorus',
#   "line's",
#   'success',
#   'spawned',
#   'many',
#   'successful',
#   'productions',
#   'worldwide.',
#   'began',
#   'lengthy',
#   'run',
#   'west',
#   'end',
#   '1976',
#   'revived',
#   'broadway',
#   '2006,',
#   'west',
#   'end',
#   '2013.'],
#  ['christmas',
#   'story:',
#   'musical',
#   'musical',
#   'version',
#   'film',
#   'christmas',
#   'story.',
#   'musical',
#   'music',
#   'lyrics',
#   'written',
#   'pasek',
#   '&',
#   'paul',
#   'book',
#   'joseph',
#   'robinette.',
#   'musical',
#   'takes',
#   'place',
#   '1940s',
#   'indiana',
#   'focuses',
#   'child',
#   'named',
#   'ralphie,',
#   'wants',
#   'red',
#   'ryder',
#   'bb',
#   'gun',
#   'christmas.\nafter',
#   'numerous',
#   'regional',
#   'productions,',
#   'town',
#   'tryouts',
#   'national',
#   'tours,',
#   'version',
#   'musical',
#   'originally',
#   'officially',
#   'opened',
#   'broadway',
#   'november',
#   '2012',
#   'lunt',
#   'fontanne',
#   'theatre',
#   'limited',
#   'engagement',
#   'ran',
#   'december',
#   '2012.'],
#  ["gentleman's",
#   'guide',
#   'love',
#   '&',
#   'murder',
#   'musical',
#   'comedy,',
#   'book',
#   'lyrics',
#   'robert',
#   'l.',
#   'freedman',
#   'music',
#   'lyrics',
#   'steven',
#   'lutvak.',
#   'based',
#   '1907',
#   'novel',
#   'israel',
#   'rank:',
#   'autobiography',
#   'criminal',
#   'roy',
#   'horniman.',
#   '',
#   'show',
#   'opened',
#   'broadway',
#   'walter',
#   'kerr',
#   'theatre',
#   'november',
#   '17,',
#   '2013,',
#   'running',
#   'january',
#   '17,',
#   '2016.',
#   'broadway',
#   'production',
#   'four',
#   'tonys',
#   '68th',
#   'tony',
#   'awards',
#   'june',
#   '2014,',
#   'including',
#   'best',
#   'musical.\nthe',
#   'novel',
#   'also',
#   'source',
#   '1949',
#   'british',
#   'film',
#   'kind',
#   'hearts',
#   'coronets;',
#   'however,',
#   'lengthy',
#   'legal',
#   'battle,',
#   'infringement',
#   'claim',
#   "film's",
#   'copyright',
#   'holder',
#   'dismissed.',
#   'small',
#   'production',
#   'show',
#   'also',
#   'performed',
#   '2004',
#   'name',
#   '1949',
#   'film.'],
#  ['little',
#   'night',
#   'music',
#   'musical',
#   'music',
#   'lyrics',
#   '',
#   'stephen',
#   'sondheim',
#   'book',
#   'hugh',
#   'wheeler.',
#   'inspired',
#   'ingmar',
#   'bergman',
#   'film',
#   'smiles',
#   'summer',
#   'night,',
#   'involves',
#   'romantic',
#   'lives',
#   'several',
#   'couples.',
#   'title',
#   'literal',
#   'english',
#   'translation',
#   'german',
#   'name',
#   "mozart's",
#   'serenade',
#   'no.',
#   '13',
#   'strings',
#   'g',
#   'major,',
#   'eine',
#   'kleine',
#   'nachtmusik.',
#   'musical',
#   'includes',
#   'popular',
#   'song',
#   '"send',
#   'clowns".\nsince',
#   'original',
#   '1973',
#   'broadway',
#   'production,',
#   'musical',
#   'enjoyed',
#   'professional',
#   'productions',
#   'west',
#   'end,',
#   'opera',
#   'companies,',
#   '2009',
#   'broadway',
#   'revival,',
#   'elsewhere,',
#   'popular',
#   'choice',
#   'regional',
#   'groups.',
#   'adapted',
#   'film',
#   '1977,',
#   'harold',
#   'prince',
#   'directing',
#   'elizabeth',
#   'taylor,',
#   'len',
#   'cariou,',
#   'lesley-anne',
#   'down,',
#   'diana',
#   'rigg',
#   'starring.'],
#  ['night',
#   'janis',
#   'joplin',
#   'broadway',
#   'musical',
#   'includes',
#   'works',
#   'singer-songwriter',
#   'janis',
#   'joplin',
#   '(1943–1970).',
#   '',
#   '22',
#   'previews,',
#   'officially',
#   'opened',
#   'lyceum',
#   'theatre',
#   'october',
#   '10,',
#   '2013,',
#   'closed',
#   'february,',
#   '141',
#   'performances.the',
#   'musical',
#   'presented',
#   'janis',
#   'joplin,',
#   'backed',
#   'band',
#   'hippies,',
#   'performing',
#   'concert',
#   '1970,',
#   'shortly',
#   'fact',
#   'died',
#   'drug',
#   'overdose,',
#   'age',
#   '27.',
#   '',
#   'among',
#   'reviews,',
#   'new',
#   'york',
#   'post',
#   'characterized',
#   'sanitizing',
#   'janis',
#   'joplin',
#   'serving',
#   'vehicle',
#   '"power-piped"',
#   'mary',
#   'bridget',
#   'davies',
#   'mostly',
#   '"stick',
#   'music".its',
#   'broadway',
#   'run',
#   '$3.9',
#   'million',
#   'production,',
#   '$650,000',
#   'budgeted',
#   'off-broadway',
#   'run',
#   'scheduled',
#   'open',
#   'gramercy',
#   'theatre.',
#   '',
#   'revival,',
#   'however,',
#   'abruptly',
#   'cancelled',
#   'april',
#   '2014,',
#   'two',
#   'days',
#   'open.the',
#   'show',
#   'performed',
#   'tour,',
#   'including',
#   'pasadena,',
#   'california.'],
#  ['tale',
#   'two',
#   'cities',
#   'musical',
#   'book,',
#   'music',
#   'lyrics',
#   'jill',
#   'santoriello',
#   'based',
#   'novel',
#   'name',
#   'charles',
#   'dickens.\nafter',
#   'tryouts',
#   'asolo',
#   'repertory',
#   'theatre',
#   'sarasota,',
#   'florida,',
#   'october',
#   'november',
#   '2007,',
#   'show',
#   'opened',
#   'broadway',
#   'september',
#   '18,',
#   '2008,',
#   'following',
#   'previews',
#   'august',
#   '19',
#   'al',
#   'hirschfeld',
#   'theatre.',
#   '',
#   'musical',
#   'closed',
#   'november',
#   '9,',
#   '2008,',
#   'run',
#   '60',
#   'performances',
#   '33',
#   'previews.',
#   'show',
#   'received',
#   '2009',
#   'outer',
#   'critics',
#   'circle',
#   'award',
#   'nomination',
#   'outstanding',
#   'new',
#   'musical',
#   'broadway',
#   'run.',
#   'james',
#   'barbour',
#   '',
#   'received',
#   '2009',
#   'drama',
#   'desk',
#   'award',
#   'nomination',
#   'performance',
#   'sydney',
#   'carton.'],
#  ['midnight',
#   'broadway',
#   'musical',
#   'premiered',
#   'brooks',
#   'atkinson',
#   'theatre',
#   '2013.',
#   'revue',
#   'based',
#   'earlier',
#   '2011',
#   'revue,',
#   'titled',
#   'cotton',
#   'club',
#   'parade,',
#   'ran',
#   'concert',
#   'encores!',
#   '2011',
#   '2012.'],
#  ['aladdin',
#   'broadway',
#   'musical',
#   'based',
#   '1992',
#   'disney',
#   'animated',
#   'film',
#   'name',
#   'book',
#   'chad',
#   'beguelin,',
#   'music',
#   'alan',
#   'menken',
#   'lyrics',
#   'howard',
#   'ashman,',
#   'tim',
#   'rice',
#   'beguelin.',
#   'resurrects',
#   'three',
#   'songs',
#   'written',
#   'menken',
#   'ashman',
#   'film',
#   'used,',
#   'adds',
#   'four',
#   'songs',
#   'written',
#   'menken',
#   'beguelin.\nset',
#   'fictional',
#   'arabian',
#   'city',
#   'agrabah,',
#   'story',
#   'follows',
#   'familiar',
#   'tale',
#   'poor',
#   'young',
#   'man',
#   'granted',
#   'three',
#   'wishes',
#   'genie',
#   'lamp,',
#   'uses',
#   'woo',
#   'princess',
#   'thwart',
#   "sultan's",
#   'evil',
#   'grand',
#   'vizier.\naladdin',
#   'premiered',
#   '5th',
#   'avenue',
#   'theatre',
#   'seattle',
#   '2011.',
#   'several',
#   'regional',
#   'international',
#   'productions',
#   '2012,',
#   'musical',
#   'given',
#   'toronto',
#   'tryout',
#   '2013.',
#   'broadway',
#   'production',
#   'opened',
#   'new',
#   'amsterdam',
#   'theatre',
#   'march',
#   '20,',
#   '2014',
#   'produced',
#   'globally',
#   'since.'],
#  ['us',
#   'musical',
#   'book',
#   'joseph',
#   'stein,',
#   'lyrics',
#   'fred',
#   'ebb,',
#   'music',
#   'john',
#   'kander.',
#   'musical',
#   'produced',
#   'regional',
#   'theatres',
#   'new',
#   'york',
#   'city.\nbased',
#   'thornton',
#   "wilder's",
#   'pulitzer',
#   'prize-winning',
#   'classic',
#   'comedy',
#   'skin',
#   'teeth,',
#   'prehistoric',
#   'antrobus',
#   'family',
#   'maid',
#   'deal',
#   "life's",
#   'trials',
#   'tribulations,',
#   'including',
#   'ice',
#   'age,',
#   'great',
#   'flood,',
#   'devastating',
#   'war',
#   'traverse',
#   'centuries',
#   'testament',
#   'human',
#   'resilience.'],
#  ['allegiance',
#   'musical',
#   'music',
#   'lyrics',
#   'jay',
#   'kuo',
#   'book',
#   'marc',
#   'acito,',
#   'kuo',
#   'lorenzo',
#   'thione.',
#   'story,',
#   'set',
#   'japanese',
#   'american',
#   'internment',
#   'world',
#   'war',
#   'ii',
#   '(with',
#   'framing',
#   'story',
#   'set',
#   'present',
#   'day),',
#   'inspired',
#   'personal',
#   'experiences',
#   'george',
#   'takei,',
#   'stars',
#   'musical.',
#   'follows',
#   'kimura',
#   'family',
#   'years',
#   'following',
#   'attack',
#   'pearl',
#   'harbor,',
#   'forced',
#   'leave',
#   'farm',
#   'salinas,',
#   'california',
#   'sent',
#   'heart',
#   'mountain',
#   'internment',
#   'camp',
#   'rural',
#   'plains',
#   'wyoming.\nthe',
#   'musical',
#   'began',
#   'development',
#   '2008',
#   'premiered',
#   'september',
#   '2012',
#   'san',
#   'diego,',
#   'california.',
#   'played',
#   'broadway',
#   'october',
#   '2015',
#   'february',
#   '2016.',
#   'reviews',
#   'broadway',
#   'mixed,',
#   'although',
#   'cast',
#   'generally',
#   'praised.'],
#  ['amazing',
#   'grace',
#   'musical',
#   'music',
#   'lyrics',
#   'christopher',
#   'smith',
#   'book',
#   'smith',
#   'arthur',
#   'giron.',
#   'musical',
#   "smith's",
#   'first',
#   'foray',
#   'professional',
#   'writer',
#   'composer.',
#   'based',
#   'loosely',
#   'life',
#   'john',
#   'newton,',
#   'english',
#   'slave',
#   'trader',
#   'later',
#   'became',
#   'anglican',
#   'priest',
#   'eventually',
#   'abolitionist.',
#   'wrote',
#   'many',
#   'hymns,',
#   'including',
#   '"amazing',
#   'grace".\nthe',
#   'musical',
#   '2012',
#   'production',
#   'goodspeed',
#   'musicals',
#   'connecticut',
#   'pre-broadway',
#   'run',
#   'chicago',
#   '2014.',
#   'opened',
#   'broadway',
#   'july',
#   '16,',
#   '2015',
#   'closed',
#   'october',
#   '25,',
#   '2015.'],
#  ['american',
#   'idiot',
#   'sung-through',
#   'rock',
#   'musical',
#   'based',
#   '2004',
#   'concept',
#   'album',
#   'name',
#   'punk',
#   'rock',
#   'band',
#   'green',
#   'day.',
#   'run',
#   'berkeley',
#   'repertory',
#   'theatre',
#   '2009,',
#   'show',
#   'moved',
#   'st.',
#   'james',
#   'theatre',
#   'broadway.',
#   'previews',
#   'began',
#   'march',
#   '24,',
#   '2010,',
#   'musical',
#   'officially',
#   'opened',
#   'april',
#   '20,',
#   '2010.',
#   'show',
#   'closed',
#   'april',
#   '24,',
#   '2011,',
#   '422',
#   'performances.',
#   'green',
#   'day',
#   'appear',
#   'production,',
#   'vocalist/guitarist',
#   'billie',
#   'joe',
#   'armstrong',
#   'performed',
#   'role',
#   '"st.',
#   'jimmy"',
#   'occasionally',
#   'throughout',
#   'run.\nthe',
#   'story,',
#   'expanded',
#   'album,',
#   'centres',
#   'three',
#   'disaffected',
#   'young',
#   'men,',
#   'johnny,',
#   'tunny.',
#   'johnny',
#   'tunny',
#   'flee',
#   'stifling',
#   'suburban',
#   'lifestyle',
#   'parental',
#   'restrictions,',
#   'stays',
#   'home',
#   'work',
#   'relationship',
#   'pregnant',
#   'girlfriend,',
#   'heather.',
#   'former',
#   'pair',
#   'look',
#   'meaning',
#   'life',
#   'try',
#   'freedom',
#   'excitement',
#   'city.',
#   'tunny',
#   'quickly',
#   'gives',
#   'life',
#   'city,',
#   'joins',
#   'military',
#   'shipped',
#   'war.',
#   'johnny',
#   'turns',
#   'drugs',
#   'finds',
#   'part',
#   'grows',
#   'dislike,',
#   'relationship',
#   'experiences',
#   'lost',
#   'love.\nthe',
#   'book',
#   'written',
#   'armstrong',
#   'director',
#   'michael',
#   'mayer.',
#   'music',
#   'composed',
#   'green',
#   'day',
#   'lyrics',
#   'armstrong.',
#   'score',
#   'included',
#   'songs',
#   'original',
#   'american',
#   'idiot',
#   'album,',
#   'well',
#   'additional',
#   'green',
#   'day',
#   'songs',
#   '2009',
#   'concept',
#   'album',
#   '21st',
#   'century',
#   'breakdown,',
#   '"when',
#   'time",',
#   'song',
#   'originally',
#   'recorded',
#   'musical.\nthe',
#   'musical',
#   'two',
#   'tony',
#   'awards:',
#   'best',
#   'scenic',
#   'design',
#   'musical',
#   'christine',
#   'jones',
#   'best',
#   'lighting',
#   'design',
#   'musical',
#   'kevin',
#   'adams.',
#   'also',
#   'received',
#   'nomination',
#   'best',
#   'musical.',
#   '2011,',
#   'broadway',
#   'cast',
#   'recording',
#   'grammy',
#   'award',
#   'best',
#   'musical',
#   'show',
#   'album.'],
#  ['american',
#   'psycho',
#   'musical',
#   'music',
#   'lyrics',
#   'duncan',
#   'sheik',
#   'book',
#   'roberto',
#   'aguirre-sacasa.',
#   'based',
#   'controversial',
#   '1991',
#   'novel',
#   'american',
#   'psycho',
#   'bret',
#   'easton',
#   'ellis,',
#   'also',
#   'inspired',
#   '2000',
#   'film',
#   'name,',
#   'starred',
#   'christian',
#   'bale.',
#   'set',
#   'manhattan',
#   'wall',
#   'street',
#   'boom',
#   'late',
#   '1980s,',
#   'american',
#   'psycho',
#   'daily',
#   'life',
#   'patrick',
#   'bateman,',
#   'wealthy',
#   'young',
#   'investment',
#   'banker',
#   'also',
#   'serial',
#   'killer.\nthe',
#   'musical',
#   'received',
#   'world',
#   'premiere',
#   "london's",
#   'almeida',
#   'theatre',
#   '2013,',
#   'directed',
#   'rupert',
#   'goold',
#   'starring',
#   'doctor',
#   'actor',
#   'matt',
#   'smith.',
#   'broadway',
#   'production',
#   'began',
#   'preview',
#   'performances',
#   '24',
#   'march',
#   '2016,',
#   'gerald',
#   'schoenfeld',
#   'theatre,',
#   'directed',
#   'goold',
#   'starring',
#   'benjamin',
#   'walker',
#   'patrick',
#   'bateman.'],
#  ['american',
#   'paris',
#   'musical',
#   'play',
#   'inspired',
#   '1951',
#   'academy',
#   'award-winning',
#   'film',
#   'name',
#   'adapted',
#   'stage',
#   'christopher',
#   'wheeldon.',
#   'opened',
#   'palace',
#   'theatre',
#   'broadway',
#   'april',
#   '2015,',
#   'following',
#   'engagement',
#   'théâtre',
#   'du',
#   'châtelet',
#   'paris.',
#   'incorporating',
#   'songs',
#   'george',
#   'ira',
#   'gershwin,',
#   'book',
#   'craig',
#   'lucas.',
#   'musical',
#   'several',
#   'tony',
#   'awards.the',
#   'broadway',
#   'production',
#   'closed',
#   'october',
#   '2016.',
#   'us',
#   'national',
#   'tour',
#   'opened',
#   'autumn',
#   '2016',
#   'boston,',
#   'massachusetts,',
#   'london',
#   'west',
#   'end',
#   'production',
#   'opened',
#   'dominion',
#   'theatre',
#   'march',
#   '2017.',
#   'italian',
#   'premiere',
#   'took',
#   'place',
#   'genoa',
#   'teatro',
#   'carlo',
#   'felice',
#   'october',
#   '2018.'],
#  ['annie',
#   'broadway',
#   'musical',
#   'based',
#   'upon',
#   'popular',
#   'harold',
#   'gray',
#   'comic',
#   'strip',
#   'little',
#   'orphan',
#   'annie,',
#   'music',
#   'charles',
#   'strouse,',
#   'lyrics',
#   'martin',
#   'charnin,',
#   'book',
#   'thomas',
#   'meehan.',
#   'original',
#   'broadway',
#   'production',
#   'opened',
#   '1977',
#   'ran',
#   'nearly',
#   'six',
#   'years,',
#   'setting',
#   'record',
#   'alvin',
#   'theatre',
#   '(now',
#   'neil',
#   'simon',
#   'theatre).',
#   'spawned',
#   'numerous',
#   'productions',
#   'many',
#   'countries,',
#   'well',
#   'national',
#   'tours,',
#   'tony',
#   'award',
#   'best',
#   'musical.',
#   "musical's",
#   'songs',
#   '"tomorrow"',
#   '"it\'s',
#   'hard',
#   'knock',
#   'life"',
#   'among',
#   'popular',
#   'musical',
#   'numbers.'],
#  ['anything',
#   'goes',
#   '1934',
#   'musical',
#   'music',
#   'lyrics',
#   'cole',
#   'porter.',
#   'original',
#   'book',
#   'collaborative',
#   'effort',
#   'guy',
#   'bolton',
#   'p.',
#   'g.',
#   'wodehouse,',
#   'heavily',
#   'revised',
#   'team',
#   'howard',
#   'lindsay',
#   'russel',
#   'crouse.',
#   'story',
#   'concerns',
#   'madcap',
#   'antics',
#   'aboard',
#   'ocean',
#   'liner',
#   'bound',
#   'new',
#   'york',
#   'london.',
#   'billy',
#   'crocker',
#   'stowaway',
#   'love',
#   'heiress',
#   'hope',
#   'harcourt,',
#   'engaged',
#   'lord',
#   'evelyn',
#   'oakleigh.',
#   'nightclub',
#   'singer',
#   'reno',
#   'sweeney',
#   'public',
#   'enemy',
#   '#13,',
#   '“moonface”',
#   'martin,',
#   'aid',
#   'billy',
#   'quest',
#   'win',
#   'hope.',
#   'musical',
#   'introduced',
#   'songs',
#   '"anything',
#   'goes",',
#   '"you\'re',
#   'top",',
#   '"i',
#   'get',
#   'kick',
#   'you."\nsince',
#   '1934',
#   'debut',
#   'alvin',
#   'theatre',
#   '(now',
#   'known',
#   'neil',
#   'simon',
#   'theatre)',
#   'broadway,',
#   'musical',
#   'revived',
#   'several',
#   'times',
#   'united',
#   'states',
#   'britain',
#   'filmed',
#   'twice.',
#   'musical',
#   'long',
#   'popular',
#   'choice',
#   'school',
#   'community',
#   'productions.'],
#  ['avenue',
#   'q',
#   'musical',
#   'comedy',
#   'featuring',
#   'puppets',
#   'human',
#   'actors',
#   'music',
#   'lyrics',
#   'robert',
#   'lopez',
#   'jeff',
#   'marx',
#   'book',
#   'jeff',
#   'whitty.',
#   'show',
#   'best',
#   'musical,',
#   'book,',
#   'score',
#   '2004',
#   'tony',
#   'awards.',
#   'show',
#   'directed',
#   'jason',
#   'moore',
#   'puppets',
#   'designed',
#   'built',
#   'original',
#   'cast',
#   'member',
#   'rick',
#   'lyon.',
#   'avenue',
#   'q',
#   'received',
#   'many',
#   'favorable',
#   'reviews',
#   'approach',
#   'topics',
#   'like',
#   'racism.\nthe',
#   'show',
#   'first',
#   'opened',
#   '2003',
#   'vineyard',
#   'theatre',
#   'co-produced',
#   'vineyard',
#   'theatre',
#   'new',
#   'group.',
#   'july',
#   'year',
#   'show',
#   'moved',
#   'john',
#   'golden',
#   'theatre',
#   'broadway.',
#   'avenue',
#   'q',
#   'would',
#   'go',
#   'play',
#   '2,500',
#   'performances,',
#   'ranking',
#   '24th',
#   'list',
#   'longest',
#   'running',
#   'shows',
#   'broadway',
#   'history,',
#   'moving',
#   'new',
#   'world',
#   'stages',
#   'play',
#   'final',
#   'performance',
#   'april',
#   '28,',
#   '2019.',
#   'show’s',
#   'success',
#   'broadway',
#   'many',
#   'international',
#   'tours',
#   'spawned',
#   'places',
#   'like',
#   'germany,',
#   'england,',
#   'hong',
#   'kong.',
#   'tours',
#   'went',
#   'on,',
#   'school',
#   'friendly',
#   'script',
#   'produced.',
#   'rights',
#   'musical',
#   'also',
#   'released.\nthe',
#   'principal',
#   'cast',
#   'includes',
#   '4',
#   'puppeteers',
#   '3',
#   'human',
#   'actors.',
#   'puppets,',
#   'princeton,',
#   'kate,',
#   'nicky,',
#   'others,',
#   'played',
#   'unconcealed',
#   'puppeteers',
#   'alongside',
#   'costumed',
#   'human',
#   'actors.',
#   'show’s',
#   'format',
#   'parody',
#   "pbs's",
#   'sesame',
#   'street.'],
#  ['baby',
#   'you!',
#   'jukebox',
#   'musical',
#   'written',
#   'floyd',
#   'mutrux',
#   'colin',
#   'escott,',
#   'featuring',
#   'music',
#   '1960s',
#   'pop',
#   'group',
#   'shirelles.',
#   'show',
#   '"tells',
#   'story',
#   'florence',
#   'greenberg',
#   'scepter',
#   'records,',
#   'label',
#   'greenberg',
#   'started',
#   'signed',
#   'shirelles."',
#   'several',
#   'tryouts',
#   'premieres,',
#   'show',
#   'debuted',
#   'broadway',
#   'april',
#   '2011,',
#   'directed',
#   'sheldon',
#   'epps.'],
#  ['beautiful:',
#   'carole',
#   'king',
#   'musical',
#   'jukebox',
#   'musical',
#   'book',
#   'douglas',
#   'mcgrath',
#   'tells',
#   'story',
#   'early',
#   'life',
#   'career',
#   'carole',
#   'king,',
#   'using',
#   'songs',
#   'wrote,',
#   'often',
#   'together',
#   'gerry',
#   'goffin,',
#   'contemporary',
#   'songs',
#   'barry',
#   'mann,',
#   'cynthia',
#   'weil,',
#   'phil',
#   'spector',
#   'others.\nthe',
#   'original',
#   'production',
#   'beautiful',
#   'received',
#   'world',
#   'premiere',
#   'curran',
#   'theatre,',
#   'san',
#   'francisco,',
#   'october',
#   '2013,',
#   'direction',
#   'marc',
#   'bruni',
#   'choreography',
#   'josh',
#   'prince,',
#   'starring',
#   'jessie',
#   'mueller',
#   'jake',
#   'epstein',
#   'carole',
#   'king',
#   'gerry',
#   'goffin.',
#   'made',
#   'broadway',
#   'debut',
#   'stephen',
#   'sondheim',
#   'theatre',
#   'january',
#   '2014.',
#   'west',
#   'end',
#   'production',
#   'starring',
#   'katie',
#   'brayben',
#   'carole',
#   'began',
#   'february',
#   '2015.',
#   'u.s.',
#   'tour',
#   'launched',
#   'september',
#   '2015.'],
#  ['big',
#   'fish',
#   'musical',
#   'music',
#   'lyrics',
#   'andrew',
#   'lippa',
#   'book',
#   'john',
#   'august.',
#   'based',
#   'daniel',
#   'wallace’s',
#   '1998',
#   'novel,',
#   'big',
#   'fish:',
#   'novel',
#   'mythic',
#   'proportions,',
#   '2003',
#   'film',
#   'big',
#   'fish',
#   'written',
#   'john',
#   'august',
#   'directed',
#   'tim',
#   'burton.\nbig',
#   'fish',
#   'revolves',
#   'around',
#   'relationship',
#   'edward',
#   'bloom,',
#   'travelling',
#   'salesman,',
#   'adult',
#   'son',
#   'will,',
#   'looks',
#   'behind',
#   'father’s',
#   'tall',
#   'stories.'],
#  ['billy',
#   'elliot',
#   'musical',
#   'musical',
#   'based',
#   '2000',
#   'film',
#   'billy',
#   'elliot.',
#   'music',
#   'elton',
#   'john,',
#   'book',
#   'lyrics',
#   'lee',
#   'hall,',
#   'wrote',
#   "film's",
#   'screenplay.',
#   'plot',
#   'revolves',
#   'around',
#   'billy,',
#   'motherless',
#   'british',
#   'boy',
#   'trades',
#   'boxing',
#   'gloves',
#   'ballet',
#   'shoes.',
#   'story',
#   'personal',
#   'struggle',
#   'fulfillment',
#   'balanced',
#   'counter-story',
#   'family',
#   'community',
#   'strife',
#   'caused',
#   '1984–85',
#   'uk',
#   "miners'",
#   'strike',
#   'county',
#   'durham,',
#   'north',
#   'eastern',
#   'england.',
#   "hall's",
#   'screenplay',
#   'inspired',
#   'part',
#   'a.',
#   'j.',
#   "cronin's",
#   '1935',
#   'novel',
#   "miners'",
#   'strike,',
#   'stars',
#   'look',
#   'down,',
#   "musical's",
#   'opening',
#   'song',
#   'pays',
#   'homage.the',
#   'musical',
#   'premiered',
#   'victoria',
#   'palace',
#   'theatre',
#   "london's",
#   'west',
#   'end',
#   '2005',
#   'nominated',
#   'nine',
#   'laurence',
#   'olivier',
#   'awards,',
#   'winning',
#   'four,',
#   'including',
#   'best',
#   'new',
#   'musical.',
#   'production',
#   'ran',
#   'april',
#   '2016.',
#   'success',
#   'led',
#   'productions',
#   'australia,',
#   'broadway',
#   'elsewhere.',
#   'new',
#   'york,',
#   'ten',
#   'tony',
#   'awards',
#   'ten',
#   'drama',
#   'desk',
#   'awards,',
#   'including,',
#   'case,',
#   'best',
#   'musical.',
#   'also',
#   'numerous',
#   'awards',
#   'australia',
#   'including',
#   'record-tying',
#   'seven',
#   'helpmann',
#   'awards.\na',
#   'live',
#   'recording',
#   'musical',
#   'released',
#   'dvd',
#   'blu-ray',
#   '24',
#   'november',
#   '2014',
#   'united',
#   'kingdom.'],
#  ['bloody',
#   'bloody',
#   'andrew',
#   'jackson',
#   'rock',
#   'musical',
#   'music',
#   'lyrics',
#   'written',
#   'michael',
#   'friedman',
#   'book',
#   'written',
#   'director',
#   'alex',
#   'timbers.the',
#   'show',
#   'comedic',
#   'historical',
#   'rock',
#   'musical',
#   'founding',
#   'democratic',
#   'party.',
#   'redefines',
#   'andrew',
#   'jackson,',
#   "america's",
#   'seventh',
#   'president,',
#   'emo',
#   'rock',
#   'star',
#   'focuses',
#   'populism,',
#   'indian',
#   'removal',
#   'act,',
#   'relationship',
#   'wife',
#   'rachel.'],
#  ['bonnie',
#   '&',
#   'clyde',
#   'musical',
#   'music',
#   'frank',
#   'wildhorn,',
#   'lyrics',
#   'black',
#   'book',
#   'ivan',
#   'menchell.',
#   'world',
#   'premiere',
#   'took',
#   'place',
#   'la',
#   'jolla,',
#   'california',
#   'november',
#   '2009.',
#   'musical',
#   'centers',
#   'bonnie',
#   'parker',
#   'clyde',
#   'barrow,',
#   'ill-fated',
#   'lovers',
#   'outlaws',
#   'whose',
#   'story',
#   'infamous',
#   'since',
#   'achieved',
#   'folk',
#   'hero',
#   'status',
#   'great',
#   'depression.',
#   'wildhorn',
#   'described',
#   'music',
#   '"non-traditional',
#   'score,',
#   'combining',
#   'rockabilly,',
#   'blues',
#   'gospel',
#   'music".',
#   'la',
#   'jolla',
#   'run',
#   'followed',
#   'sarasota,',
#   'florida',
#   'engagement',
#   '2010.\nthe',
#   'musical',
#   'debuted',
#   'broadway',
#   'december',
#   '2011,',
#   'failed',
#   'impress',
#   'critics.',
#   'ticket',
#   'sales',
#   'poor,',
#   'closed',
#   'four',
#   'weeks.',
#   'nominated',
#   '3',
#   'outer',
#   'critics',
#   'circle',
#   'awards',
#   '5',
#   'drama',
#   'desk',
#   'awards,',
#   'including',
#   'best',
#   'new',
#   'musical,',
#   'well',
#   'two',
#   'nominations',
#   '2012',
#   'tony',
#   'awards.',
#   'subsequent',
#   'productions',
#   'since',
#   'staged',
#   'internationally',
#   'following',
#   'submission',
#   'work',
#   'music',
#   'theater',
#   'international,',
#   'including',
#   'productions',
#   'japan,',
#   'korea',
#   'u.k.'],
#  ['bright',
#   'star',
#   'musical',
#   'written',
#   'composed',
#   'steve',
#   'martin',
#   'edie',
#   'brickell.',
#   'set',
#   'blue',
#   'ridge',
#   'mountains',
#   'north',
#   'carolina',
#   '1945-46',
#   'flashbacks',
#   '1923.',
#   'musical',
#   'inspired',
#   'grammy-winning',
#   'collaboration',
#   '',
#   '2013',
#   'bluegrass',
#   'album',
#   'love',
#   'come',
#   'you.'],
#  ['bring',
#   'on:',
#   'musical',
#   'musical',
#   'music',
#   'tom',
#   'kitt',
#   'lin-manuel',
#   'miranda,',
#   'lyrics',
#   'amanda',
#   'green',
#   'miranda,',
#   'book',
#   'jeff',
#   'whitty.',
#   'musical,',
#   'loosely',
#   'based',
#   '2000',
#   'film',
#   'name',
#   'written',
#   'jessica',
#   'bendinger,',
#   'focuses',
#   'competitive',
#   'world',
#   'cheerleading',
#   'over-the-top',
#   'team',
#   'rivalries.\nthe',
#   'musical',
#   'premiered',
#   'alliance',
#   'theatre',
#   'atlanta,',
#   'georgia',
#   'january',
#   '2011.',
#   'cast',
#   'included',
#   'amanda',
#   'lea',
#   'lavergne',
#   'campbell,',
#   'adrienne',
#   'warren',
#   'danielle,',
#   'nick',
#   'blaemire',
#   'randall,',
#   'ryann',
#   'redmond',
#   'bridget,',
#   '"award-winning',
#   'competitive',
#   'cheerleaders',
#   'across',
#   'country".',
#   'national',
#   'tour',
#   'musical',
#   'played',
#   'major',
#   'u.s.',
#   'cities',
#   'november',
#   '2011',
#   'june',
#   '2012.\nthe',
#   'touring',
#   'stage',
#   'production',
#   'began',
#   'previews',
#   'broadway',
#   'july',
#   '2012',
#   'st.',
#   'james',
#   'theatre,',
#   'opening',
#   'limited',
#   'engagement',
#   'august',
#   '1,',
#   '2012,',
#   'december',
#   '30,',
#   '2012.'],
#  ['bullets',
#   'broadway',
#   'musical',
#   'musical',
#   'written',
#   'woody',
#   'allen,',
#   'based',
#   'douglas',
#   "mcgrath's",
#   'film',
#   'bullets',
#   'broadway',
#   'young',
#   'playwright',
#   'whose',
#   'first',
#   'broadway',
#   'play',
#   'financed',
#   'gangster.',
#   'score',
#   'consists',
#   'jazz',
#   'popular',
#   'standards',
#   'years',
#   'world',
#   'war',
#   '1930',
#   'various',
#   'songwriters.',
#   'received',
#   'premiere',
#   'broadway,',
#   '2014,',
#   'st.',
#   'james',
#   'theatre,',
#   'closed',
#   'august',
#   '24,',
#   '2014',
#   'hundred',
#   'performances.'],
#  ['burn',
#   'floor',
#   'live',
#   'dance',
#   'show',
#   'performed',
#   'around',
#   'world,',
#   'including',
#   'broadway',
#   'new',
#   'york',
#   'city',
#   'west',
#   'end',
#   'london.',
#   'since',
#   '1997,',
#   'burn',
#   'floor',
#   'performed',
#   '130',
#   'countries',
#   'worldwide.',
#   'show',
#   'also',
#   'featured',
#   'several',
#   'alumni',
#   'various',
#   'international',
#   'versions',
#   'dancing',
#   'stars',
#   'think',
#   'dance.'],
#  ['bye',
#   'bye',
#   'birdie',
#   'stage',
#   'musical',
#   'book',
#   'michael',
#   'stewart,',
#   'lyrics',
#   'lee',
#   'adams',
#   'music',
#   'charles',
#   'strouse.\noriginally',
#   'titled',
#   "let's",
#   'go',
#   'steady,',
#   'bye',
#   'bye',
#   'birdie',
#   'set',
#   '1958.',
#   'story',
#   'inspired',
#   'phenomenon',
#   'popular',
#   'singer',
#   'elvis',
#   'presley',
#   'draft',
#   'notice',
#   'army',
#   '1957.',
#   'rock',
#   'star',
#   "character's",
#   'name,',
#   '"conrad',
#   'birdie",',
#   'word',
#   'play',
#   'name',
#   'conway',
#   'twitty.',
#   'twitty',
#   'best',
#   'remembered',
#   'today',
#   'long',
#   'career',
#   'country',
#   'music',
#   'star,',
#   'late',
#   '1950s,',
#   'one',
#   "presley's",
#   'rock',
#   "'n'",
#   'roll',
#   'rivals.',
#   '\nthe',
#   'original',
#   '1960–1961',
#   'broadway',
#   'production',
#   'tony',
#   'award–winning',
#   'success.',
#   'spawned',
#   'london',
#   'production',
#   'several',
#   'major',
#   'revivals,',
#   'sequel,',
#   '1963',
#   'film,',
#   '1995',
#   'television',
#   'production.',
#   'show',
#   'also',
#   'became',
#   'popular',
#   'choice',
#   'high',
#   'school',
#   'college',
#   'productions.'],
#  ['cabaret',
#   '1966',
#   'musical',
#   'music',
#   'john',
#   'kander,',
#   'lyrics',
#   'fred',
#   'ebb,',
#   'book',
#   'joe',
#   'masteroff,',
#   'based',
#   'john',
#   'van',
#   "druten's",
#   '1951',
#   'play',
#   'camera,',
#   'adapted',
#   'short',
#   'novel',
#   'goodbye',
#   'berlin',
#   '(1939)',
#   'christopher',
#   'isherwood.',
#   'set',
#   '1931',
#   'berlin',
#   'nazis',
#   'rising',
#   'power,',
#   'focuses',
#   'nightlife',
#   'seedy',
#   'kit',
#   'kat',
#   'klub,',
#   'revolves',
#   'around',
#   'american',
#   'writer',
#   'cliff',
#   'bradshaw',
#   'relationship',
#   'english',
#   'cabaret',
#   'performer',
#   'sally',
#   'bowles.\na',
#   'sub-plot',
#   'involves',
#   'doomed',
#   'romance',
#   'german',
#   'boarding',
#   'house',
#   'owner',
#   'fräulein',
#   'schneider',
#   'elderly',
#   'suitor',
#   'herr',
#   'schultz,',
#   'jewish',
#   'fruit',
#   'vendor.',
#   'overseeing',
#   'action',
#   'master',
#   'ceremonies',
#   'kit',
#   'kat',
#   'klub.',
#   'club',
#   'serves',
#   'metaphor',
#   'ominous',
#   'political',
#   'developments',
#   'late',
#   'weimar',
#   'germany.\nthe',
#   '1966',
#   'original',
#   'broadway',
#   'production',
#   'became',
#   'hit,',
#   'inspiring',
#   'numerous',
#   'subsequent',
#   'productions',
#   'london',
#   'new',
#   'york,',
#   'well',
#   '1972',
#   'film',
#   'name.'],
#  ['catch',
#   'musical',
#   'libretto',
#   'terrence',
#   'mcnally',
#   'theatrical',
#   'score',
#   'marc',
#   'shaiman',
#   'scott',
#   'wittman.',
#   'follows',
#   'story',
#   'con',
#   'artist',
#   'named',
#   'frank',
#   'abagnale',
#   'jr.',
#   'majority',
#   'plot',
#   'borrowed',
#   '2002',
#   'film',
#   'name,',
#   'turn',
#   'based',
#   '1980',
#   'autobiography',
#   'name',
#   'abagnale',
#   'stan',
#   'redding.\nafter',
#   'tryout',
#   'musical',
#   'performance',
#   'seattle',
#   '2009,',
#   'catch',
#   'opened',
#   "broadway's",
#   'neil',
#   'simon',
#   'theatre',
#   'april',
#   '2011.',
#   'production',
#   'received',
#   'four',
#   'tony',
#   'awards',
#   'nominations,',
#   'including',
#   'one',
#   'best',
#   'musical,',
#   'winning',
#   'best',
#   'actor',
#   'musical',
#   'norbert',
#   'leo',
#   'butz.'],
#  ['cats',
#   'sung-through',
#   'musical',
#   'composed',
#   'andrew',
#   'lloyd',
#   'webber,',
#   'based',
#   'old',
#   "possum's",
#   'book',
#   'practical',
#   'cats',
#   't.',
#   's.',
#   'eliot.',
#   'musical',
#   'tells',
#   'story',
#   'tribe',
#   'cats',
#   'called',
#   'jellicles',
#   'night',
#   'make',
#   'known',
#   '"the',
#   'jellicle',
#   'choice"',
#   'decide',
#   'cat',
#   'ascend',
#   'heaviside',
#   'layer',
#   'come',
#   'back',
#   'new',
#   'life.\ndirected',
#   'trevor',
#   'nunn',
#   'choreographed',
#   'gillian',
#   'lynne,',
#   'cats',
#   'first',
#   'opened',
#   'west',
#   'end',
#   '1981',
#   'creative',
#   'team',
#   'broadway',
#   '1982.',
#   'numerous',
#   'awards,',
#   'including',
#   'best',
#   'musical',
#   'laurence',
#   'olivier',
#   'awards',
#   'tony',
#   'awards.',
#   'london',
#   'production',
#   'ran',
#   '21',
#   'years',
#   'broadway',
#   'production',
#   'ran',
#   '18',
#   'years,',
#   'setting',
#   'new',
#   'records.',
#   'actresses',
#   'elaine',
#   'paige',
#   'betty',
#   'buckley',
#   'became',
#   'particularly',
#   'associated',
#   'musical.',
#   'one',
#   'actress,',
#   'marlene',
#   'danielle,',
#   'performed',
#   'broadway',
#   'production',
#   'entire',
#   'run',
#   '(from',
#   '1982',
#   '2000).as',
#   '2018,',
#   'cats',
#   'fourth-longest-running',
#   'show',
#   'broadway',
#   'history,',
#   'longest-running',
#   'broadway',
#   'show',
#   'history',
#   '1997',
#   '2006',
#   'surpassed',
#   'phantom',
#   'opera.',
#   'cats',
#   'sixth-longest-running',
#   'west',
#   'end',
#   'show.',
#   'performed',
#   'around',
#   'world',
#   'many',
#   'times',
#   'translated',
#   '20',
#   'languages.',
#   'musical',
#   'adapted',
#   'direct-to-video',
#   'film',
#   '1998,',
#   '2019',
#   'film',
#   'adaptation',
#   'tom',
#   'hooper',
#   'set',
#   'follow.\nthe',
#   'original',
#   'broadway',
#   'production',
#   'grossed',
#   'approximately',
#   '$388',
#   'million',
#   '(not',
#   'adjusted',
#   'inflation).'],
#  ['chaplin:',
#   'musical,',
#   'formerly',
#   'titled',
#   'limelight:',
#   'story',
#   'charlie',
#   'chaplin,',
#   'musical',
#   'music',
#   'lyrics',
#   'christopher',
#   'curtis',
#   'book',
#   'curtis',
#   'thomas',
#   'meehan.',
#   'show',
#   'based',
#   'life',
#   'charlie',
#   'chaplin.',
#   'musical,',
#   'started',
#   'new',
#   'york',
#   'musical',
#   'theatre',
#   'festival',
#   '2006,',
#   'debuted',
#   'la',
#   'jolla',
#   'playhouse',
#   '2010,',
#   'premiered',
#   'broadway',
#   '2012.'],
#  ['chicago',
#   '(chicago:',
#   'musical',
#   'vaudeville)',
#   'american',
#   'musical',
#   'music',
#   'john',
#   'kander,',
#   'lyrics',
#   'fred',
#   'ebb,',
#   'book',
#   'ebb',
#   'bob',
#   'fosse.',
#   'set',
#   'jazz-age',
#   'chicago,',
#   'musical',
#   'based',
#   '1926',
#   'play',
#   'name',
#   'reporter',
#   'maurine',
#   'dallas',
#   'watkins',
#   'actual',
#   'criminals',
#   'crimes',
#   'reported',
#   'on.',
#   'story',
#   'satire',
#   'corruption',
#   'administration',
#   'criminal',
#   'justice',
#   'concept',
#   '"celebrity',
#   'criminal".\nthe',
#   'original',
#   'broadway',
#   'production',
#   'opened',
#   '1975',
#   '46th',
#   'street',
#   'theatre',
#   'ran',
#   '936',
#   'performances',
#   '1977.',
#   'bob',
#   'fosse',
#   'choreographed',
#   'original',
#   'production,',
#   'style',
#   'strongly',
#   'identified',
#   'show.',
#   'following',
#   'west',
#   'end',
#   'debut',
#   '1979',
#   'ran',
#   '600',
#   'performances,',
#   'chicago',
#   'revived',
#   'broadway',
#   '1996,',
#   'year',
#   'later',
#   'west',
#   'end.\nthe',
#   'broadway',
#   'revival',
#   'holds',
#   'record',
#   'longest-running',
#   'musical',
#   'revival',
#   'longest-running',
#   'american',
#   'musical',
#   'broadway',
#   'history.',
#   'second',
#   'longest-running',
#   'show',
#   'broadway',
#   'history,',
#   'behind',
#   'phantom',
#   'opera,',
#   'played',
#   '7,486th',
#   'performance',
#   'november',
#   '23,',
#   '2014,',
#   'surpassing',
#   'cats.',
#   'west',
#   'end',
#   'revival',
#   'became',
#   'longest-running',
#   'american',
#   'musical',
#   'west',
#   'end',
#   'history.',
#   '',
#   'chicago',
#   'staged',
#   'numerous',
#   'productions',
#   'around',
#   'world,',
#   'toured',
#   'extensively',
#   'united',
#   'states',
#   'united',
#   'kingdom.',
#   '2002',
#   'film',
#   'version',
#   'musical',
#   'academy',
#   'award',
#   'best',
#   'picture.'],
#  ['rodgers',
#   "hammerstein's",
#   'cinderella',
#   'musical',
#   'written',
#   'television,',
#   'later',
#   'played',
#   'stage,',
#   'music',
#   'richard',
#   'rodgers',
#   'book',
#   'lyrics',
#   'oscar',
#   'hammerstein',
#   'ii.',
#   '',
#   'based',
#   'upon',
#   'fairy',
#   'tale',
#   'cinderella,',
#   'particularly',
#   'french',
#   'version',
#   'cendrillon,',
#   'ou',
#   'la',
#   'petite',
#   'pantoufle',
#   'de',
#   'verre,',
#   'charles',
#   'perrault.',
#   'story',
#   'concerns',
#   'young',
#   'woman',
#   'forced',
#   'life',
#   'servitude',
#   'cruel',
#   'stepmother',
#   'self-centered',
#   'stepsisters,',
#   'dreams',
#   'better',
#   'life.',
#   'help',
#   'fairy',
#   'godmother,',
#   'cinderella',
#   'transformed',
#   'princess',
#   'finds',
#   'prince.\ncinderella',
#   'rodgers',
#   'hammerstein',
#   'musical',
#   'written',
#   'television.',
#   'originally',
#   'broadcast',
#   'live',
#   'cbs',
#   'march',
#   '31,',
#   '1957',
#   'vehicle',
#   'julie',
#   'andrews,',
#   'played',
#   'title',
#   'role.',
#   'broadcast',
#   'viewed',
#   '100',
#   'million',
#   'people.',
#   'subsequently',
#   'remade',
#   'television',
#   'twice,',
#   '1965',
#   '1997.',
#   '1965',
#   'version',
#   'starred',
#   'lesley',
#   'ann',
#   'warren',
#   'stuart',
#   'damon,',
#   '1997',
#   'one',
#   'starred',
#   'brandy',
#   'norwood',
#   'title',
#   'role,',
#   'whitney',
#   'houston',
#   'fairy',
#   'godmother.',
#   'remakes',
#   'add',
#   'songs',
#   'richard',
#   'rodgers',
#   'musicals.\nthe',
#   'musical',
#   'adapted',
#   'stage',
#   'number',
#   'versions,',
#   'including',
#   'london',
#   'west',
#   'end',
#   'pantomime',
#   'adaptation,',
#   'new',
#   'york',
#   'city',
#   'opera',
#   'production',
#   'follows',
#   'original',
#   'television',
#   'version',
#   'closely,',
#   'various',
#   'touring',
#   'productions.',
#   '2013',
#   'adaptation',
#   'broadway',
#   'starred',
#   'laura',
#   'osnes',
#   'santino',
#   'fontana,',
#   'new',
#   'book',
#   'douglas',
#   'carter',
#   'beane.'],
#  ['come',
#   'away',
#   'musical',
#   'book,',
#   'music',
#   'lyrics',
#   'irene',
#   'sankoff',
#   'david',
#   'hein.',
#   'set',
#   'week',
#   'following',
#   'september',
#   '11',
#   'attacks',
#   'tells',
#   'true',
#   'story',
#   'transpired',
#   '38',
#   'planes',
#   'ordered',
#   'land',
#   'unexpectedly',
#   'small',
#   'town',
#   'gander',
#   'province',
#   'newfoundland',
#   'labrador,',
#   'canada,',
#   'part',
#   'operation',
#   'yellow',
#   'ribbon.',
#   'characters',
#   'musical',
#   'based',
#   '(and',
#   'cases',
#   'share',
#   'names',
#   'of)',
#   'real',
#   'gander',
#   'residents',
#   'well',
#   '7,000',
#   'stranded',
#   'travelers',
#   'housed',
#   'fed.\nthe',
#   'musical',
#   'received',
#   'audiences',
#   'critics',
#   'cathartic',
#   'reminder',
#   'capacity',
#   'human',
#   'kindness',
#   'even',
#   'darkest',
#   'times',
#   'triumph',
#   'humanity',
#   'hate.after',
#   'workshopped',
#   '2012',
#   'first',
#   'produced',
#   'sheridan',
#   'college',
#   'oakville,',
#   'ontario',
#   '2013,',
#   'went',
#   'record-breaking',
#   'runs',
#   'la',
#   'jolla',
#   'playhouse',
#   'san',
#   'diego,',
#   'california',
#   'seattle',
#   'repertory',
#   'theatre',
#   '2015,',
#   "ford's",
#   'theatre',
#   'washington,',
#   'd.c.,',
#   'royal',
#   'alexandra',
#   'theatre',
#   'toronto',
#   '2016.',
#   'opened',
#   'broadway',
#   'gerald',
#   'schoenfeld',
#   'theatre',
#   'march',
#   '12,',
#   '2017,',
#   'became',
#   'critical',
#   'box',
#   'office',
#   'success,',
#   'routinely',
#   'playing',
#   'standing-room-only',
#   'audiences',
#   'even',
#   'previews.',
#   'october',
#   '2018',
#   'became',
#   'longest-running',
#   'canadian',
#   'musical',
#   'broadway',
#   'history,',
#   'surpassing',
#   'drowsy',
#   "chaperone's",
#   'previous',
#   'record',
#   '674',
#   'performances.baz',
#   'bamigboye',
#   'announced',
#   'twitter',
#   'june',
#   '7,',
#   '2018',
#   'london',
#   'production',
#   'come',
#   'away',
#   'would',
#   'coming',
#   'february',
#   '2019.',
#   'said',
#   'show',
#   'would',
#   'first',
#   'premiere',
#   'abbey',
#   'theatre',
#   'dublin',
#   'december',
#   'would',
#   'transfer',
#   'phoenix',
#   'theatre.',
#   'also',
#   'stated',
#   'official',
#   'announcement',
#   'would',
#   'come',
#   'canada',
#   'day.\nat',
#   '71st',
#   'tony',
#   'awards,',
#   'nominated',
#   'seven',
#   'awards',
#   'including',
#   'best',
#   'musical,',
#   'best',
#   'original',
#   'score,',
#   'best',
#   'book',
#   'musical',
#   'best',
#   'featured',
#   'actress',
#   'musical',
#   'jenn',
#   'colella,',
#   'ultimately',
#   'winning',
#   'best',
#   'direction',
#   'musical',
#   'christopher',
#   'ashley.'],
#  ['cry-baby',
#   'musical',
#   'based',
#   '1990',
#   'john',
#   'waters',
#   'film',
#   'name.',
#   'music',
#   'david',
#   'javerbaum',
#   'adam',
#   'schlesinger,',
#   'book',
#   'mark',
#   "o'donnell",
#   'thomas',
#   'meehan.',
#   "o'donnell",
#   'meehan',
#   'also',
#   'adapted',
#   "waters'",
#   'film',
#   'hairspray',
#   'musical',
#   'stage.',
#   'musical',
#   'focuses',
#   'baltimore',
#   'teenager',
#   'allison',
#   'vernon-williams,',
#   'drawn',
#   'across',
#   'tracks',
#   '1954',
#   'finishing-school',
#   'background',
#   'relationship',
#   'orphaned',
#   'wade',
#   '"cry-baby"',
#   'walker,',
#   'leader',
#   'pack',
#   'rebel',
#   'outcasts.'],
#  ['curtains',
#   'musical',
#   'mystery',
#   'comedy',
#   'book',
#   'rupert',
#   'holmes,',
#   'lyrics',
#   'fred',
#   'ebb,',
#   'music',
#   'john',
#   'kander,',
#   'additional',
#   'lyrics',
#   'kander',
#   'holmes.\nbased',
#   'original',
#   'book',
#   'concept',
#   'name',
#   'peter',
#   'stone,',
#   'musical',
#   'send-up',
#   'backstage',
#   'murder',
#   'mystery',
#   'plots,',
#   'set',
#   '1959',
#   'boston,',
#   'massachusetts',
#   'follows',
#   'fallout',
#   'jessica',
#   'cranshaw,',
#   'supremely',
#   'untalented',
#   'star',
#   "robbin'",
#   'hood',
#   'old',
#   'west',
#   'murdered',
#   'opening',
#   'night',
#   'curtain',
#   'call.',
#   '',
#   'lt.',
#   'frank',
#   'cioffi,',
#   'police',
#   'detective',
#   'moonlights',
#   'musical',
#   'theater',
#   'fan',
#   'save',
#   'show,',
#   'solve',
#   'case,',
#   'maybe',
#   'even',
#   'find',
#   'love',
#   'show',
#   'reopens,',
#   'without',
#   'getting',
#   'killed',
#   'himself.',
#   'cioffi',
#   'also',
#   'dreams',
#   'musical',
#   'theater.',
#   'show',
#   'opened',
#   'broadway',
#   'mixed',
#   'reviews,',
#   'though',
#   'several',
#   'critics',
#   'praised',
#   'libretto',
#   'character',
#   'lieutenant',
#   'cioffi,',
#   'critic',
#   'ben',
#   'brantley',
#   'called',
#   '"the',
#   'best',
#   'damn',
#   'musical',
#   'theatre',
#   'character',
#   'since',
#   'mama',
#   'rose',
#   "'gypsy',",
#   'best',
#   'role',
#   'david',
#   'hyde',
#   "pierce's",
#   'career."'],
#  ['dames',
#   'sea',
#   'musical',
#   'book',
#   'lyrics',
#   'george',
#   'haimsohn',
#   'robin',
#   'miller',
#   'music',
#   'jim',
#   'wise.\nthe',
#   'musical',
#   'parody',
#   'large,',
#   'flashy',
#   '1930s',
#   'busby',
#   'berkeley-style',
#   'movie',
#   'musicals',
#   'chorus',
#   'girl,',
#   'newly',
#   'arrived',
#   'bus',
#   'midwest',
#   'new',
#   'york',
#   'city,',
#   'steps',
#   'role',
#   'broadway',
#   'becomes',
#   'star.',
#   '',
#   'originally',
#   'played',
#   'off-off-broadway',
#   '1966',
#   'caffe',
#   'cino',
#   'played',
#   'off-broadway,',
#   'starring',
#   'newcomer',
#   'bernadette',
#   'peters,',
#   'beginning',
#   '1968',
#   'successful',
#   'run.',
#   '',
#   'show',
#   'enjoyed',
#   'london',
#   'run,',
#   'television',
#   'adaptation',
#   'number',
#   'revivals,',
#   'broadway',
#   'premiere',
#   'october',
#   '2015.'],
#  ['disaster!',
#   'musical',
#   'comedy',
#   'created',
#   'seth',
#   'rudetsky,',
#   'written',
#   'seth',
#   'rudetsky',
#   'jack',
#   'plotnick.',
#   '',
#   'earthquakes,',
#   'tidal',
#   'waves,',
#   'infernos',
#   '',
#   'songs',
#   "'70s",
#   'take',
#   'center',
#   'stage',
#   'homage',
#   'classic',
#   'disaster',
#   'films.\nthe',
#   'show',
#   'debuted',
#   'triad',
#   'theatre,',
#   'renamed',
#   'stage',
#   '72,',
#   'choreography',
#   'denis',
#   'jones',
#   'music',
#   'supervision',
#   'steve',
#   'marzullo',
#   'january',
#   '22,',
#   '2012',
#   'ran',
#   'march',
#   '25',
#   'first',
#   'production.',
#   'second',
#   'production',
#   'ran',
#   'november',
#   '2013',
#   'april',
#   '2014',
#   'new',
#   "york's",
#   'st.',
#   "luke's",
#   'theatre.',
#   'show',
#   'opened',
#   'broadway',
#   'nederlander',
#   'theatre',
#   'march',
#   '8,',
#   '2016,',
#   'previews',
#   'beginning',
#   'february',
#   '9,',
#   '2016.',
#   '',
#   'show',
#   'starred',
#   'rudetsky,',
#   'along',
#   'roger',
#   'bart,',
#   'kerry',
#   'butler,',
#   'kevin',
#   'chamberlin,',
#   'adam',
#   'pascal,',
#   'faith',
#   'prince,',
#   'rachel',
#   'york,',
#   'max',
#   'crumm,',
#   'jennifer',
#   'simard.',
#   '',
#   'baylee',
#   'littrell',
#   '(the',
#   'son',
#   'brian',
#   'littrell)',
#   'lacretta',
#   'nicole',
#   'made',
#   'broadway',
#   'debut.',
#   'show',
#   'closed',
#   'may',
#   '8,',
#   '2016,',
#   'playing',
#   '32',
#   'previews',
#   '72',
#   'regular',
#   'performances.disaster!',
#   'parodies',
#   'pays',
#   'comedic',
#   'tribute',
#   'genre',
#   '1970s',
#   'disaster',
#   'films.',
#   'musical,',
#   'group',
#   'new',
#   'yorkers',
#   'attends',
#   'opening',
#   'floating',
#   'casino',
#   'discothèque',
#   'quickly',
#   'succumbs',
#   'multiple',
#   'disasters.',
#   'calamities',
#   'correlate',
#   'plots',
#   'various',
#   'disaster',
#   'films',
#   '1970s,',
#   'earthquakes',
#   'killer',
#   'bee',
#   'incidents,',
#   'echoing',
#   'situations',
#   'films',
#   'earthquake',
#   'swarm',
#   'respectively.',
#   'additionally,',
#   'play',
#   'keeps',
#   '1970s',
#   'theme',
#   'jukebox',
#   'musical,',
#   'using',
#   'popular',
#   'songs',
#   'decade',
#   'musical',
#   'numbers.'],
#  ['doctor',
#   'zhivago',
#   '–',
#   'new',
#   'musical',
#   '2011',
#   'musical',
#   'composed',
#   'lucy',
#   'simon,',
#   'lyrics',
#   'michael',
#   'korie',
#   'amy',
#   'powers,',
#   'book',
#   'michael',
#   'weller;',
#   'based',
#   'boris',
#   "pasternak's",
#   '1957',
#   'novel',
#   'doctor',
#   'zhivago.'],
#  ['grinch',
#   'stole',
#   'christmas!',
#   '(also',
#   'known',
#   'dr.',
#   "seuss'",
#   'grinch',
#   'stole',
#   'christmas!',
#   'simply',
#   'grinch',
#   'uk)',
#   '2000',
#   'american',
#   'christmas',
#   'fantasy',
#   'comedy',
#   'film',
#   'directed',
#   'ron',
#   'howard',
#   'written',
#   'jeffrey',
#   'price',
#   'peter',
#   's.',
#   'seaman.',
#   'based',
#   'dr.',
#   "seuss's",
#   '1957',
#   'book',
#   'name,',
#   'film',
#   'first',
#   'dr.',
#   'seuss',
#   'book',
#   'adapted',
#   'full-length',
#   'feature',
#   'film.',
#   'film',
#   'stars',
#   'jim',
#   'carrey',
#   'title',
#   'role,',
#   'jeffrey',
#   'tambor,',
#   'christine',
#   'baranski,',
#   'bill',
#   'irwin,',
#   'molly',
#   'shannon',
#   'taylor',
#   'momsen.\nbecause',
#   'film',
#   'based',
#   "children's",
#   'picture',
#   'book,',
#   'many',
#   'additions',
#   'made',
#   'storyline',
#   'bring',
#   'feature-length,',
#   'including',
#   'information',
#   'backstory',
#   'title',
#   'character',
#   'reworking',
#   "story's",
#   'minor',
#   'character',
#   'cindy',
#   'lou',
#   'main',
#   'character.',
#   'rhymes',
#   'used',
#   'book',
#   'also',
#   'used',
#   'film,',
#   'though',
#   'lines',
#   'degree',
#   'changed',
#   'several',
#   'new',
#   'rhymes',
#   'put',
#   'in.',
#   'film',
#   'also',
#   'borrowed',
#   'music',
#   'character',
#   'elements',
#   '(such',
#   "grinch's",
#   'green',
#   'skin',
#   'tone)',
#   'originated',
#   '1966',
#   'animated',
#   'television',
#   'special.\nproduced',
#   'howard',
#   'brian',
#   "grazer's",
#   'imagine',
#   'entertainment,',
#   'dr.',
#   "seuss'",
#   'grinch',
#   'stole',
#   'christmas!',
#   'released',
#   'universal',
#   'pictures',
#   'november',
#   '17,',
#   '2000',
#   'mixed',
#   'reviews',
#   'critics,',
#   "carrey's",
#   'performance',
#   'favorably',
#   'praised.',
#   'film',
#   'grossed',
#   '$345',
#   'million',
#   'worldwide,',
#   'becoming',
#   'sixth-highest',
#   'grossing',
#   'film',
#   '2000',
#   'originally',
#   'second',
#   'highest-grossing',
#   'holiday',
#   'film',
#   'all-time',
#   'behind',
#   'home',
#   'alone',
#   '(1990),',
#   'movies',
#   'surpassed',
#   '2018',
#   'second',
#   'film',
#   'adaptation',
#   'story.',
#   'academy',
#   'award',
#   'best',
#   'makeup',
#   'well',
#   'getting',
#   'nominations',
#   'best',
#   'art',
#   'direction',
#   'best',
#   'costume',
#   'design.'],
#  ['elf',
#   'musical',
#   'based',
#   'motion',
#   'picture',
#   'name,',
#   'score',
#   'matthew',
#   'sklar',
#   'chad',
#   'beguelin.',
#   'book',
#   'adapted',
#   'bob',
#   'martin',
#   'thomas',
#   'meehan',
#   '2003',
#   'film.',
#   'musical',
#   'ran',
#   'broadway',
#   'christmas',
#   'seasons',
#   '2010-11',
#   '2012–13,',
#   'also',
#   'toured',
#   'u.s.',
#   '2012.',
#   'new',
#   'tour',
# ...
#   'cast',
#   'recording',
#   'became',
#   'highest-charting',
#   'broadway',
#   'cast',
#   'album',
#   'four',
#   'decades,',
#   'reaching',
#   'number',
#   'three',
#   'billboard',
#   'charts.',
#   '2013,',
#   'musical',
#   'premiered',
#   'west',
#   'end,',
#   'followed',
#   'two',
#   'us',
#   'national',
#   'tours.',
#   'production',
#   'melbourne',
#   'first',
#   'non-english',
#   'version,',
#   'stockholm,',
#   'opened',
#   'january',
#   '2017.',
#   'productions',
#   'oslo',
#   'copenhagen',
#   'followed.',
#   '\nthe',
#   'book',
#   'mormon',
#   'grossed',
#   '$500',
#   'million,',
#   'making',
#   'one',
#   'successful',
#   'musicals',
#   'time.'],
#  ['bridges',
#   'madison',
#   'county',
#   'musical,',
#   'based',
#   'robert',
#   'james',
#   "waller's",
#   '1992',
#   'novel,',
#   'book',
#   'marsha',
#   'norman',
#   'music',
#   'lyrics',
#   'jason',
#   'robert',
#   'brown.',
#   'musical',
#   'premiered',
#   'broadway',
#   'gerald',
#   'schoenfeld',
#   'theatre',
#   'february',
#   '20,',
#   '2014,',
#   'closed',
#   'may',
#   '18,',
#   '2014.',
#   'broadway',
#   'production',
#   'directed',
#   'bartlett',
#   'sher',
#   'starred',
#   'kelli',
#   "o'hara",
#   'francesca',
#   'steven',
#   'pasquale',
#   'robert.',
#   "brown's",
#   'work',
#   'musical',
#   '2014',
#   'tony',
#   'awards',
#   '"best',
#   'original',
#   'score"',
#   '"best',
#   'orchestrations"',
#   'broadway',
#   'production',
#   'already',
#   'closed.'],
#  ['color',
#   'purple',
#   'musical',
#   'book',
#   'marsha',
#   'norman',
#   'music',
#   'lyrics',
#   'brenda',
#   'russell,',
#   'allee',
#   'willis,',
#   'stephen',
#   'bray.',
#   'based',
#   '1982',
#   'novel',
#   'name',
#   'alice',
#   'walker',
#   '1985',
#   'film',
#   'adaptation,',
#   'show',
#   'follows',
#   'journey',
#   'celie,',
#   'african-american',
#   'woman',
#   'american',
#   'south',
#   'early',
#   'mid-20th',
#   'century.\nthe',
#   'original',
#   'broadway',
#   'production',
#   'ran',
#   '2005',
#   '2008,',
#   'earning',
#   'eleven',
#   'tony',
#   'award',
#   'nominations',
#   '2006.',
#   'enthusiastically',
#   '',
#   'acclaimed',
#   'broadway',
#   'revival',
#   'opened',
#   'late',
#   '2015',
#   'ran',
#   'early',
#   '2017,',
#   'winning',
#   'two',
#   '2016',
#   'tony',
#   'awards—including',
#   'best',
#   'revival',
#   'musical.'],
#  ['color',
#   'purple',
#   'musical',
#   'book',
#   'marsha',
#   'norman',
#   'music',
#   'lyrics',
#   'brenda',
#   'russell,',
#   'allee',
#   'willis,',
#   'stephen',
#   'bray.',
#   'based',
#   '1982',
#   'novel',
#   'name',
#   'alice',
#   'walker',
#   '1985',
#   'film',
#   'adaptation,',
#   'show',
#   'follows',
#   'journey',
#   'celie,',
#   'african-american',
#   'woman',
#   'american',
#   'south',
#   'early',
#   'mid-20th',
#   'century.\nthe',
#   'original',
#   'broadway',
#   'production',
#   'ran',
#   '2005',
#   '2008,',
#   'earning',
#   'eleven',
#   'tony',
#   'award',
#   'nominations',
#   '2006.',
#   'enthusiastically',
#   '',
#   'acclaimed',
#   'broadway',
#   'revival',
#   'opened',
#   'late',
#   '2015',
#   'ran',
#   'early',
#   '2017,',
#   'winning',
#   'two',
#   '2016',
#   'tony',
#   'awards—including',
#   'best',
#   'revival',
#   'musical.'],
#  ['king',
#   'fifth',
#   'musical',
#   'team',
#   'composer',
#   'richard',
#   'rodgers',
#   'dramatist',
#   'oscar',
#   'hammerstein',
#   'ii.',
#   '',
#   'based',
#   'margaret',
#   "landon's",
#   'novel,',
#   'anna',
#   'king',
#   'siam',
#   '(1944),',
#   'turn',
#   'derived',
#   'memoirs',
#   'anna',
#   'leonowens,',
#   'governess',
#   'children',
#   'king',
#   'mongkut',
#   'siam',
#   'early',
#   '1860s.',
#   '',
#   "musical's",
#   'plot',
#   'relates',
#   'experiences',
#   'anna,',
#   'british',
#   'schoolteacher',
#   'hired',
#   'part',
#   "king's",
#   'drive',
#   'modernize',
#   'country.',
#   '',
#   'relationship',
#   'king',
#   'anna',
#   'marked',
#   'conflict',
#   'much',
#   'piece,',
#   'well',
#   'love',
#   'neither',
#   'admit.',
#   'musical',
#   'premiered',
#   'march',
#   '29,',
#   '1951,',
#   "broadway's",
#   'st.',
#   'james',
#   'theatre.',
#   '',
#   'ran',
#   'nearly',
#   'three',
#   'years,',
#   'making',
#   'fourth',
#   'longest-running',
#   'broadway',
#   'musical',
#   'history',
#   'time,',
#   'many',
#   'tours',
#   'revivals.\nin',
#   '1950,',
#   'theatrical',
#   'attorney',
#   'fanny',
#   'holtzmann',
#   'looking',
#   'part',
#   'client,',
#   'veteran',
#   'leading',
#   'lady',
#   'gertrude',
#   'lawrence.',
#   '',
#   'holtzmann',
#   'realized',
#   "landon's",
#   'book',
#   'would',
#   'provide',
#   'ideal',
#   'vehicle',
#   'contacted',
#   'rodgers',
#   'hammerstein,',
#   'initially',
#   'reluctant',
#   'agreed',
#   'write',
#   'musical.',
#   '',
#   'pair',
#   'initially',
#   'sought',
#   'rex',
#   'harrison',
#   'play',
#   'supporting',
#   'part',
#   'king,',
#   'role',
#   'played',
#   '1946',
#   'film',
#   'made',
#   "landon's",
#   'book,',
#   'unavailable.',
#   '',
#   'settled',
#   'young',
#   'actor',
#   'television',
#   'director',
#   'yul',
#   'brynner.\nthe',
#   'musical',
#   'immediate',
#   'hit,',
#   'winning',
#   'tony',
#   'awards',
#   'best',
#   'musical,',
#   'best',
#   'actress',
#   '(for',
#   'lawrence)',
#   'best',
#   'featured',
#   'actor',
#   '(for',
#   'brynner).',
#   '',
#   'lawrence',
#   'died',
#   'unexpectedly',
#   'cancer',
#   'year',
#   'half',
#   'opening,',
#   'role',
#   'anna',
#   'played',
#   'several',
#   'actresses',
#   'remainder',
#   'broadway',
#   'run',
#   '1,246',
#   'performances.',
#   '',
#   'hit',
#   'london',
#   'run',
#   'u.s.',
#   'national',
#   'tour',
#   'followed,',
#   'together',
#   '1956',
#   'film',
#   'brynner',
#   'academy',
#   'award,',
#   'musical',
#   'recorded',
#   'several',
#   'times.',
#   '',
#   'later',
#   'revivals,',
#   'brynner',
#   'came',
#   'dominate',
#   'role',
#   'musical,',
#   'starring',
#   'four-year',
#   'national',
#   'tour',
#   'culminating',
#   '1985',
#   'broadway',
#   'run',
#   'shortly',
#   'death.\nchristopher',
#   'renshaw',
#   'directed',
#   'major',
#   'revivals',
#   'broadway',
#   '(1996),',
#   'winning',
#   '',
#   'tony',
#   'award',
#   'best',
#   'revival,',
#   'west',
#   'end',
#   '(2000).',
#   '2015',
#   'broadway',
#   'revival',
#   'another',
#   'tony',
#   'best',
#   'revival.',
#   'professional',
#   'amateur',
#   'revivals',
#   'king',
#   'continue',
#   'staged',
#   'regularly',
#   'throughout',
#   'english-speaking',
#   'world.'],
#  ['last',
#   'ship',
#   'original',
#   'musical',
#   'music',
#   'lyrics',
#   'sting',
#   'book',
#   'john',
#   'logan',
#   'brian',
#   'yorkey.',
#   'inspired',
#   "sting's",
#   'childhood',
#   'experiences',
#   'shipbuilding',
#   'industry',
#   'wallsend,',
#   'tyne',
#   'wear,',
#   'musical',
#   'premiered',
#   'summer',
#   '2014,',
#   'bank',
#   'america',
#   'theatre',
#   'chicago,',
#   'moving',
#   'neil',
#   'simon',
#   'theatre',
#   'broadway.',
#   'musical',
#   'received',
#   'two',
#   'tony',
#   'award',
#   'nominations',
#   '2015,',
#   'best',
#   'original',
#   'score',
#   'best',
#   'orchestrations.'],
#  ['lion',
#   'king',
#   'musical',
#   'based',
#   '1994',
#   'walt',
#   'disney',
#   'animation',
#   "studios'",
#   'animated',
#   'feature',
#   'film',
#   'name',
#   'music',
#   'elton',
#   'john,',
#   'lyrics',
#   'tim',
#   'rice,',
#   'book',
#   'roger',
#   'allers',
#   'irene',
#   'mecchi,',
#   'along',
#   'additional',
#   'music',
#   'lyrics',
#   'lebo',
#   'm,',
#   'mark',
#   'mancina,',
#   'jay',
#   'rifkin,',
#   'julie',
#   'taymor,',
#   'hans',
#   'zimmer.',
#   'directed',
#   'taymor,',
#   'musical',
#   'features',
#   'actors',
#   'animal',
#   'costumes',
#   'well',
#   'giant,',
#   'hollow',
#   'puppets.',
#   'show',
#   'produced',
#   'disney',
#   'theatrical',
#   'productions.the',
#   'musical',
#   'debuted',
#   'july',
#   '8,',
#   '1997',
#   'minneapolis,',
#   'minnesota',
#   'orpheum',
#   'theatre',
#   'instant',
#   'success',
#   'premiering',
#   'broadway',
#   'new',
#   'amsterdam',
#   'theater',
#   'october',
#   '15,',
#   '1997',
#   'many',
#   'previews',
#   'official',
#   'opening',
#   'november',
#   '13,',
#   '1997.',
#   '',
#   'june',
#   '13,',
#   '2006,',
#   'broadway',
#   '',
#   'production',
#   'moved',
#   'minskoff',
#   'theatre',
#   'make',
#   'way',
#   'musical',
#   'version',
#   'mary',
#   'poppins,',
#   'still',
#   'running',
#   '8,500',
#   'performances.',
#   '',
#   "broadway's",
#   'third',
#   'longest-running',
#   'show',
#   'history,',
#   'grossed',
#   '$1',
#   'billion,',
#   'making',
#   'highest',
#   'grossing',
#   'broadway',
#   'production',
#   'time.',
#   '',
#   '95',
#   'million',
#   'people',
#   'worldwide',
#   'seen',
#   'musical',
#   'earned',
#   'numerous',
#   'awards',
#   'honors,',
#   'including',
#   'six',
#   'tony',
#   'awards,',
#   'one',
#   'best',
#   'musical',
#   'best',
#   'direction',
#   'musical,',
#   'making',
#   'director',
#   'julie',
#   'taymor',
#   'first',
#   'woman',
#   'earn',
#   'honor.the',
#   'show',
#   'opened',
#   'west',
#   "end's",
#   'lyceum',
#   'theatre',
#   'october',
#   '19,',
#   '1999,',
#   'still',
#   'running',
#   '7,500',
#   'performances.',
#   'cast',
#   'west',
#   'end',
#   'production',
#   'invited',
#   'perform',
#   'royal',
#   'variety',
#   'performance',
#   '1999',
#   '2008,',
#   'presence',
#   'senior',
#   'members',
#   'british',
#   'royal',
#   'family.in',
#   'september',
#   '2014,',
#   'lion',
#   'king',
#   'became',
#   'top-earning',
#   'title',
#   'box-office',
#   'history',
#   'stage',
#   'productions',
#   'films,',
#   'surpassing',
#   'record',
#   'previously',
#   'held',
#   'phantom',
#   'opera.',
#   'lion',
#   'king',
#   'musical',
#   'grossed',
#   'nearly',
#   '$8.1',
#   'billion',
#   '2017.'],
#  ['little',
#   'mermaid',
#   'stage',
#   'musical',
#   'produced',
#   'disney',
#   'theatrical,',
#   'based',
#   'animated',
#   '1989',
#   'disney',
#   'film',
#   'name',
#   'classic',
#   'story',
#   'name',
#   'hans',
#   'christian',
#   'andersen',
#   'mermaid',
#   'dreams',
#   'world',
#   'sea',
#   'gives',
#   'voice',
#   'find',
#   'love.',
#   'book',
#   'doug',
#   'wright,',
#   'music',
#   'alan',
#   'menken',
#   'lyrics',
#   'howard',
#   'ashman',
#   '(written',
#   'film),',
#   'additional',
#   'lyrics',
#   'glenn',
#   'slater.',
#   'underwater',
#   'setting',
#   'story',
#   'aquatic',
#   'characters',
#   'requires',
#   'unusual',
#   'technical',
#   'designs',
#   'strategies',
#   'create',
#   'gliding',
#   'movements',
#   'actors.\nafter',
#   'pre-broadway',
#   'tryout',
#   'denver,',
#   'colorado',
#   'july',
#   'september',
#   '2007,',
#   'musical',
#   'began',
#   'broadway',
#   'previews',
#   'november',
#   '3,',
#   '2007',
#   'lunt-fontanne',
#   'theatre,',
#   'replacing',
#   "disney's",
#   'beauty',
#   'beast.',
#   'production',
#   'officially',
#   'opened',
#   'january',
#   '10,',
#   '2008',
#   'closed',
#   'august',
#   '30,',
#   '2009',
#   '685',
#   'performances',
#   '50',
#   'previews.',
#   'introduced',
#   'broadway',
#   'debuts',
#   'director',
#   'francesca',
#   'zambello',
#   'sierra',
#   'boggess',
#   'title',
#   'role.\nsubsequent',
#   'productions',
#   'seen',
#   'us',
#   'regional',
#   'theatres',
#   'internationally.',
#   'modified',
#   'version',
#   'musical',
#   'new',
#   'book',
#   'direction',
#   'glenn',
#   'casale',
#   'developed',
#   '2012,',
#   'version',
#   'basis',
#   'subsequent',
#   'productions.\n\n'],
#  ['mystery',
#   'edwin',
#   'drood',
#   '(or',
#   'simply',
#   'drood)',
#   'musical',
#   'based',
#   'unfinished',
#   'charles',
#   'dickens',
#   'novel',
#   'mystery',
#   'edwin',
#   'drood.',
#   '',
#   'written',
#   'rupert',
#   'holmes,',
#   'first',
#   'broadway',
#   'musical',
#   'multiple',
#   'endings',
#   '(determined',
#   'audience',
#   'vote).',
#   'holmes',
#   'received',
#   'tony',
#   'awards',
#   'best',
#   'book',
#   'musical',
#   'best',
#   'original',
#   'score.',
#   '',
#   'musical',
#   'five',
#   'tony',
#   'awards',
#   'eleven',
#   'nominations,',
#   'including',
#   'best',
#   'musical',
#   'best',
#   'performance',
#   'leading',
#   'actor',
#   'musical.\nthe',
#   'musical',
#   'debuted',
#   'part',
#   'new',
#   'york',
#   'shakespeare',
#   'festival',
#   'august',
#   '1985,',
#   'and,',
#   'following',
#   'revision,',
#   'transferred',
#   'broadway,',
#   'ran',
#   'may',
#   '1987.',
#   'two',
#   'national',
#   'tours',
#   'production',
#   "london's",
#   'west',
#   'end',
#   'followed.',
#   '',
#   'roundabout',
#   'theatre',
#   'company',
#   'revived',
#   'musical',
#   'mystery',
#   'edwin',
#   'drood',
#   '2012.'],
#  ['people',
#   'picture',
#   'musical',
#   'book',
#   'lyrics',
#   'iris',
#   'rainer',
#   'dart',
#   'music',
#   'mike',
#   'stoller',
#   'artie',
#   'butler.',
#   'musical',
#   'grandmother',
#   'recalling',
#   'life',
#   'yiddish',
#   'theater',
#   'holocaust.'],
#  ['phantom',
#   'opera',
#   'musical',
#   'music',
#   'andrew',
#   'lloyd',
#   'webber',
#   'lyrics',
#   'charles',
#   'hart.',
#   'richard',
#   'stilgoe',
#   'lloyd',
#   'webber',
#   'wrote',
#   "musical's",
#   'book',
#   'together.',
#   'stilgoe',
#   'also',
#   'provided',
#   'additional',
#   'lyrics.',
#   'based',
#   'eponymous',
#   'french',
#   'novel',
#   'gaston',
#   'leroux,',
#   'central',
#   'plot',
#   'revolves',
#   'around',
#   'beautiful',
#   'soprano,',
#   'christine',
#   'daaé,',
#   'becomes',
#   'obsession',
#   'mysterious,',
#   'disfigured',
#   'musical',
#   'genius',
#   'living',
#   'subterranean',
#   'labyrinth',
#   'beneath',
#   'paris',
#   'opéra',
#   'house.the',
#   'musical',
#   'opened',
#   "london's",
#   'west',
#   'end',
#   '1986,',
#   'broadway',
#   '1988.',
#   '1986',
#   'olivier',
#   'award',
#   '1988',
#   'tony',
#   'award',
#   'best',
#   'musical,',
#   'michael',
#   'crawford',
#   '(in',
#   'title',
#   'role)',
#   'olivier',
#   'tony',
#   'awards',
#   'best',
#   'actor',
#   'musical.',
#   'longest',
#   'running',
#   'show',
#   'broadway',
#   'history',
#   'wide',
#   'margin,',
#   'celebrated',
#   '10,000th',
#   'broadway',
#   'performance',
#   '11',
#   'february',
#   '2012,',
#   'first',
#   'production',
#   'ever',
#   'so.',
#   'second',
#   'longest-running',
#   'west',
#   'end',
#   'musical,',
#   'les',
#   'misérables,',
#   'third',
#   'longest-running',
#   'west',
#   'end',
#   'show',
#   'overall,',
#   'mousetrap.with',
#   'total',
#   'estimated',
#   'worldwide',
#   'gross',
#   'receipts',
#   '$5.6',
#   'billion',
#   'total',
#   'broadway',
#   'gross',
#   '$845',
#   'million,',
#   'phantom',
#   'financially',
#   'successful',
#   'entertainment',
#   'event',
#   'lion',
#   'king',
#   'surpassed',
#   '2014.',
#   '2011,',
#   'seen',
#   '130',
#   'million',
#   'people',
#   '145',
#   'cities',
#   'across',
#   '27',
#   'countries,',
#   'continues',
#   'play',
#   'london',
#   'new',
#   'york.'],
#  ['scottsboro',
#   'boys',
#   'musical',
#   'book',
#   'david',
#   'thompson,',
#   'music',
#   'john',
#   'kander',
#   'lyrics',
#   'fred',
#   'ebb.',
#   'based',
#   'scottsboro',
#   'boys',
#   'trial,',
#   'musical',
#   'one',
#   'last',
#   'collaborations',
#   'kander',
#   'ebb',
#   'prior',
#   "latter's",
#   'death.',
#   'musical',
#   'framework',
#   'minstrel',
#   'show,',
#   'altered',
#   '"create',
#   'musical',
#   'social',
#   'critique"',
#   'company',
#   'that,',
#   'except',
#   'one,',
#   'consists',
#   '"entirely',
#   'african-american',
#   'performers".the',
#   'musical',
#   'debuted',
#   'off-broadway',
#   'moved',
#   'broadway',
#   '2010',
#   'run',
#   'two',
#   'months.',
#   'received',
#   'twelve',
#   'tony',
#   'award',
#   'nominations,',
#   'failed',
#   'win',
#   'any.',
#   'previous',
#   'record',
#   'nominations',
#   'without',
#   'win',
#   'eleven,',
#   'held',
#   'steel',
#   'pier',
#   'original',
#   'production',
#   'chicago,',
#   'also',
#   'kander',
#   'ebb.',
#   "musical's",
#   'twelve',
#   'nominations',
#   'second',
#   'book',
#   'mormon,',
#   'garnered',
#   'fourteen',
#   'nominations',
#   'year.',
#   'nevertheless,',
#   'scottsboro',
#   'boys',
#   'played',
#   'us',
#   'regional',
#   'theatres',
#   '2012',
#   'moved',
#   'london',
#   '2013,',
#   'where,',
#   'sell-out',
#   'production',
#   'young',
#   'vic,',
#   'moved',
#   'west',
#   'end',
#   '2014.'],
#  ['story',
#   'life',
#   'musical',
#   'music',
#   'lyrics',
#   'neil',
#   'bartram,',
#   'book',
#   'brian',
#   'hill.',
#   '',
#   'show',
#   'follows',
#   'two',
#   'childhood',
#   'friends',
#   'age',
#   'six',
#   '35',
#   'two',
#   'characters.\nthe',
#   'musical',
#   'debuted',
#   'canadian',
#   'stage',
#   'company',
#   'toronto',
#   '2006',
#   'starring',
#   'brent',
#   'carver',
#   'jeffrey',
#   'kuhn',
#   'premiered',
#   'broadway',
#   'february',
#   '2009,',
#   'closing',
#   'nineteen',
#   'previews',
#   'five',
#   'regular',
#   'performances.'],
#  ['visit',
#   'musical',
#   'book',
#   'terrence',
#   'mcnally,',
#   'lyrics',
#   'fred',
#   'ebb,',
#   'music',
#   'john',
#   'kander.\nbased',
#   'friedrich',
#   "dürrenmatt's",
#   '1956',
#   'satirical',
#   'play',
#   'greed',
#   'revenge',
#   'der',
#   'besuch',
#   'der',
#   'alten',
#   'dame,',
#   'focuses',
#   'one',
#   "world's",
#   'wealthiest',
#   'women,',
#   'claire',
#   'zachanassian,',
#   'returns',
#   'financially',
#   'depressed',
#   'hometown',
#   'offers',
#   'residents',
#   'new',
#   'lease',
#   'life',
#   'exchange',
#   'murder',
#   'anton',
#   'schell,',
#   'man',
#   'abandoned',
#   'years',
#   'ago.']]

# %% [raw]
# def sentences(reviews):
#     '''
#     This function takes a list of synopses as a parameter and returns these synopses as lists of the sentences
#     they contain.
#     '''
#     sentencestotal=[]
#     for i, review in enumerate(reviews):
#         sentlist=[]
#         for sentence in sent_tokenize(review):
#             sentlist.append(sentence)
#         sentencestotal.append(sentlist)
#
#
#     return sentencestotal

# %% [raw]
# s=sentences(reviews)
# s

# %% [markdown]
# ### Then, into words tuples within sentences ###

# %% [raw]
# #same as above, but making now just words, but word tuples
# from nltk import pos_tag, sent_tokenize, wordpunct_tokenize
#
#
# def words2():
#     """
#     Uses the built-in word tokenizer to extract tokens from sentences.
#     Note that this method uses BeautifulSoup to parse HTML content.
#     """
#     docs=[]
#     for synopsis in s:
#         sents=[]
#         for sentence in synopsis:
#             wordsinsentence=[]
#             for token in pos_tag(wordpunct_tokenize(sentence)):
#                 wordsinsentence.append(token)
#             sents.append(wordsinsentence)
#         docs.append(sents)
#     return docs

# %% [raw]
# tokenized=words2()
# len(tokenized)
# len(s)
# tokenized

# %% [raw]
# fortdidf=words()
# fortdidf

# %% [markdown]
# ## STEP 2: Vectorization ##
# ### TD-IDF Method ###

# %%
#TF-IDF, using the TextCollection class
from nltk.text import TextCollection

def vectorize(corpus):
    corpus=TextCollection(corpus)
    texts=corpus
    for doc in corpus:
        print(doc)
        print(texts.tf_idf(doc,corpus))

# %%
vectorize(reviews_nonstop)
# Out:
# 13
# 0.0012311113571719494
# original
# 0.004544062515786549
# musical
# 0.0013387699694530314
# music
# 0.0022891463912154265
# lyrics
# 0.002607676772888367
# jason
# 0.0009848890857375595
# robert
# 0.0022973020714655208
# brown
# 0.0005876963197768388
# book
# 0.0022533784788526857
# dan
# 0.0003414740483424489
# elish
# 0.0003414740483424489
# robert
# 0.0022973020714655208
# horn.
# following
# 0.0003414740483424489
# move
# 0.0003414740483424489
# new
# 0.0048522541031224605
# york
# 0.0032482693291954515
# city
# 0.001832642714430366
# small-town
# 0.0003414740483424489
# indiana,
# 0.0003414740483424489
# young
# 0.0025717979765175927
# evan
# 0.0010244221450273466
# goldman
# 0.000881544479665258
# grapples
# 0.0005876963197768388
# parents'
# 0.0003414740483424489
# divorce,
# 0.0003414740483424489
# prepares
# 0.0003414740483424489
# impending
# 0.0003414740483424489
# bar
# 0.0011753926395536775
# mitzvah,
# 0.0003414740483424489
# navigates
# 0.0003414740483424489
# complicated
# 0.0003414740483424489
# social
# 0.0013101774757515235
# circles
# 0.0003414740483424489
# new
# 0.0048522541031224605
# school.
# 0.0007979664032378502
# 13
# 0.0012311113571719494
# broadway
# 0.0033278807404973523
# musical
# 0.0013387699694530314
# ever
# 0.0013101774757515235
# cast
# 0.004163221465427338
# band
# 0.0013101774757515235
# entirely
# 0.0003414740483424489
# made
# 0.003286186303328035
# teenagers.
# 0.0003414740483424489
# originally
# 0.001588771063842883
# began
# 0.0033563310431262753
# previews
# 0.0024864786021424113
# september
# 0.0031196828087471638
# 16,
# 0.0009848890857375595
# 2008
# 0.0026507331593832936
# officially
# 0.001588771063842883
# opened
# 0.004648455978914792
# october
# 0.0034505491965885773
# 5,
# 0.0009848890857375595
# 2008
# 0.0026507331593832936
# bernard
# 0.0003414740483424489
# musical
# 0.0013387699694530314
# includes
# 0.001588771063842883
# popular
# 0.0030194098905266175
# song
# 0.0011544507994853306
# "send
# 0.0003414740483424489
# clowns".
# since
# 0.0003414740483424489
# original
# 0.004544062515786549
# 1973
# 0.0007979664032378502
# broadway
# 0.0033278807404973523
# production,
# 0.002495684983086185
# musical
# 0.0013387699694530314
# enjoyed
# 0.0017873674468232431
# professional
# 0.0014543989318156392
# productions
# 0.003880044870475363
# west
# 0.004740967854362197
# end,
# 0.0009848890857375595
# opera
# 0.0019859638298036033
# companies,
# 0.0003414740483424489
# 2009
# 0.0021205865275066346
# broadway
# 0.0033278807404973523
# revival,
# 0.0013101774757515235
# elsewhere,
# 0.0005876963197768388
# popular
# 0.0030194098905266175
# choice
# 0.0015285403883767775
# regional
# 0.001832642714430366
# groups.
# 0.0005876963197768388
# adapted
# 0.0029840444257581565
# film
# 0.005149867519328269
# 1977,
# 0.0003414740483424489
# harold
# 0.0007979664032378502
# prince
# 0.0007979664032378502
# directing
# 0.0003414740483424489
# elizabeth
# 0.0010639552043171339
# taylor,
# 0.0003414740483424489
# len
# 0.0003414740483424489
# cariou,
# 0.0003414740483424489
# lesley-anne
# 0.0003414740483424489
# down,
# 0.0005876963197768388
# diana
# 0.0009848890857375595
# rigg
# 0.0003414740483424489
# starring.
# 0.0003414740483424489
# night
# 0.0017145319843450619
# janis
# 0.0013658961933697956
# joplin
# 0.0010244221450273466
# broadway
# 0.0033278807404973523
# musical
# 0.0013387699694530314
# includes
# 0.001588771063842883
# works
# 0.0007979664032378502
# singer-songwriter
# 0.0003414740483424489
# janis
# 0.0013658961933697956
# joplin
# 0.0010244221450273466
# (1943–1970).
# 0.0003414740483424489
#
# 0.00844380941095593
# 22
# 0.0003414740483424489
# previews,
# 0.0007979664032378502
# officially
# 0.001588771063842883
# opened
# 0.004648455978914792
# lyceum
# 0.0005876963197768388
# theatre
# 0.005456407252621618
# october
# 0.0034505491965885773
# 10,
# 0.0009848890857375595
# 2013,
# 0.001832642714430366
# closed
# 0.0034489287737558784
# february,
# 0.0003414740483424489
# 141
# 0.0003414740483424489
# performances.the
# 0.0003414740483424489
# musical
# 0.0013387699694530314
# presented
# 0.0007979664032378502
# janis
# 0.0013658961933697956
# joplin,
# 0.0003414740483424489
# backed
# 0.0003414740483424489
# band
# 0.0013101774757515235
# hippies,
# 0.0003414740483424489
# performing
# 0.0007979664032378502
# concert
# 0.0013853409593823965
# 1970,
# 0.0003414740483424489
# shortly
# 0.0009848890857375595
# fact
# 0.0003414740483424489
# died
# 0.0007979664032378502
# drug
# 0.0007979664032378502
# overdose,
# 0.0003414740483424489
# age
# 0.0011544507994853306
# 27.
# 0.0003414740483424489
#
# 0.00844380941095593
# among
# 0.0020159069858734025
# reviews,
# 0.0011544507994853306
# new
# 0.0048522541031224605
# york
# 0.0032482693291954515
# post
# 0.0003414740483424489
# characterized
# 0.0003414740483424489
# sanitizing
# 0.0003414740483424489
# janis
# 0.0013658961933697956
# joplin
# 0.0010244221450273466
# serving
# 0.0005876963197768388
# vehicle
# 0.0007979664032378502
# "power-piped"
# 0.0003414740483424489
# mary
# 0.0013853409593823965
# bridget
# 0.0003414740483424489
# davies
# 0.0003414740483424489
# mostly
# 0.0005876963197768388
# "stick
# 0.0003414740483424489
# music".its
# 0.0003414740483424489
# broadway
# 0.0033278807404973523
# run
# 0.003680585809694482
# $3.9
# 0.0003414740483424489
# million
# 0.0022973020714655208
# production,
# 0.002495684983086185
# $650,000
# 0.0003414740483424489
# budgeted
# 0.0003414740483424489
# off-broadway
# 0.0032297099781115335
# run
# 0.003680585809694482
# scheduled
# 0.0009848890857375595
# open
# 0.0007979664032378502
# gramercy
# 0.0005876963197768388
# theatre.
# 0.002242035425274865
#
# 0.00844380941095593
# revival,
# 0.0013101774757515235
# however,
# 0.0013101774757515235
# abruptly
# 0.0003414740483424489
# cancelled
# 0.0003414740483424489
# april
# 0.0037436851701280684
# 2014,
# 0.002199171257316439
# two
# 0.004163221465427338
# days
# 0.0007979664032378502
# open.the
# 0.0003414740483424489
# show
# 0.005789276090102659
# performed
# 0.0029025294109108154
# tour,
# 0.0003414740483424489
# including
# 0.005274697914468527
# pasadena,
# 0.0005876963197768388
# california.
# 0.0009848890857375595
# tale
# 0.0009848890857375595
# two
# 0.004163221465427338
# cities
# 0.0011544507994853306
# musical
# 0.0013387699694530314
# book,
# 0.0014543989318156392
# music
# 0.0022891463912154265
# lyrics
# 0.002607676772888367
# jill
# 0.0005876963197768388
# santoriello
# 0.0003414740483424489
# based
# 0.0036990983567486077
# novel
# 0.0026424899820912547
# name
# 0.0030777783929298733
# charles
# 0.0014543989318156392
# dickens.
# after
# 0.0003414740483424489
# tryouts
# 0.0011544507994853306
# asolo
# 0.0003414740483424489
# repertory
# 0.0009848890857375595
# theatre
# 0.005456407252621618
# sarasota,
# 0.0005876963197768388
# florida,
# 0.0003414740483424489
# october
# 0.0034505491965885773
# november
# 0.003082904979106464
# 2007,
# 0.0009848890857375595
# show
# 0.005789276090102659
# opened
# 0.004648455978914792
# broadway
# 0.0033278807404973523
# september
# 0.0031196828087471638
# 18,
# 0.0007979664032378502
# 2008,
# 0.0022973020714655208
# following
# 0.002415527912421294
# previews
# 0.0024864786021424113
# august
# 0.002048844290054693
# 19
# 0.0007979664032378502
# al
# 0.0011544507994853306
# hirschfeld
# 0.0007979664032378502
# theatre.
# 0.002242035425274865
#
# 0.00844380941095593
# musical
# 0.0013387699694530314
# closed
# 0.0034489287737558784
# november
# 0.003082904979106464
# 9,
# 0.0011544507994853306
# 2008,
# 0.0022973020714655208
# run
# 0.003680585809694482
# 60
# 0.0005876963197768388
# performances
# 0.002714675641879681
# 33
# 0.0005876963197768388
# previews.
# 0.0009848890857375595
# show
# 0.005789276090102659
# received
# 0.003823750424675151
# 2009
# 0.0021205865275066346
# outer
# 0.0013101774757515235
# critics
# 0.0019438709835477483
# circle
# 0.001588771063842883
# award
# 0.005442493701583679
# nomination
# 0.002390318338397142
# shows
# 0.0007979664032378502
# broadway
# 0.0033278807404973523
# history,
# 0.001588771063842883
# moving
# 0.0005876963197768388
# new
# 0.0048522541031224605
# world
# 0.0030425786603414376
# stages
# 0.0003414740483424489
# play
# 0.0029690620766117046
# final
# 0.0003414740483424489
# performance
# 0.0019438709835477483
# april
# 0.0037436851701280684
# 28,
# 0.0003414740483424489
# 2019.
# 0.0007979664032378502
# show’s
# 0.0006829480966848978
# success
# 0.002048844290054693
# broadway
# 0.0033278807404973523
# many
# 0.0029224172549540167
# international
# 0.0022973020714655208
# tours
# 0.0019859638298036033
# spawned
# 0.0019438709835477483
# places
# 0.0005876963197768388
# like
# 0.0013853409593823965
# germany,
# 0.0007979664032378502
# england,
# 0.0005876963197768388
# hong
# 0.0003414740483424489
# kong.
# 0.0003414740483424489
# tours
# 0.0019859638298036033
# went
# 0.0007979664032378502
# on,
# 0.0003414740483424489
# school
# 0.002383156595764324
# friendly
# 0.0003414740483424489
# script
# 0.0005876963197768388
# produced.
# 0.0005876963197768388
# rights
# 0.0005876963197768388
# musical
# 0.0013387699694530314
# also
# 0.004486987433592793
# released.
# the
# 0.0003414740483424489
# principal
# 0.0003414740483424489
# cast
# 0.004163221465427338
# includes
# 0.001588771063842883
# 4
# 0.0003414740483424489
# puppeteers
# 0.0006829480966848978
# 3
# 0.0009848890857375595
# human
# ...
# 0.0006829480966848978
# dreams
# 0.0011544507994853306
# world
# 0.0030425786603414376
# sea
# 0.0005876963197768388
# gives
# 0.0009848890857375595
# voice
# 0.0003414740483424489
# find
# 0.0007979664032378502
# love.
# 0.0005876963197768388
# book
# 0.0022533784788526857
# doug
# 0.0005876963197768388
# wright,
# 0.0005876963197768388
# music
# 0.0022891463912154265
# alan
# 0.001588771063842883
# menken
# 0.0011753926395536775
# lyrics
# 0.002607676772888367
# howard
# 0.0013853409593823965
# ashman
# 0.0005876963197768388
# (written
# 0.0003414740483424489
# film),
# 0.0003414740483424489
# additional
# 0.001588771063842883
# lyrics
# 0.002607676772888367
# glenn
# 0.0012311113571719494
# slater.
# 0.0003414740483424489
# underwater
# 0.0003414740483424489
# setting
# 0.0007979664032378502
# story
# 0.0037562242724245567
# aquatic
# 0.0003414740483424489
# characters
# 0.002184560212783964
# requires
# 0.0003414740483424489
# unusual
# 0.0005876963197768388
# technical
# 0.0005876963197768388
# designs
# 0.0003414740483424489
# strategies
# 0.0003414740483424489
# create
# 0.0005876963197768388
# gliding
# 0.0003414740483424489
# movements
# 0.0003414740483424489
# actors.
# after
# 0.0003414740483424489
# pre-broadway
# 0.0009848890857375595
# tryout
# 0.0011544507994853306
# denver,
# 0.0005876963197768388
# colorado
# 0.0005876963197768388
# july
# 0.002048844290054693
# september
# 0.0031196828087471638
# 2007,
# 0.0009848890857375595
# musical
# 0.0013387699694530314
# began
# 0.0033563310431262753
# broadway
# 0.0033278807404973523
# previews
# 0.0024864786021424113
# november
# 0.003082904979106464
# 3,
# 0.0007979664032378502
# 2007
# 0.001662170207789302
# lunt-fontanne
# 0.0003414740483424489
# theatre,
# 0.00190503553816118
# replacing
# 0.0003414740483424489
# disney's
# 0.0003414740483424489
# beauty
# 0.0003414740483424489
# beast.
# 0.0003414740483424489
# production
# 0.005976185995036847
# officially
# 0.001588771063842883
# opened
# 0.004648455978914792
# january
# 0.0030981517321165613
# 10,
# 0.0009848890857375595
# 2008
# 0.0026507331593832936
# closed
# 0.0034489287737558784
# august
# 0.002048844290054693
# 30,
# 0.0009848890857375595
# 2009
# 0.0021205865275066346
# 685
# 0.0003414740483424489
# performances
# 0.002714675641879681
# 50
# 0.0003414740483424489
# previews.
# 0.0009848890857375595
# introduced
# 0.0009848890857375595
# broadway
# 0.0033278807404973523
# debuts
# 0.0005876963197768388
# director
# 0.001832642714430366
# francesca
# 0.0005876963197768388
# zambello
# 0.0003414740483424489
# sierra
# 0.0005876963197768388
# boggess
# 0.0005876963197768388
# title
# 0.002382435528759476
# role.
# subsequent
# 0.0003414740483424489
# productions
# 0.003880044870475363
# seen
# 0.0014543989318156392
# us
# 0.002148085148240211
# regional
# 0.001832642714430366
# theatres
# 0.0009848890857375595
# internationally.
# 0.0003414740483424489
# modified
# 0.0003414740483424489
# version
# 0.0028090344246218145
# musical
# 0.0013387699694530314
# new
# 0.0048522541031224605
# book
# 0.0022533784788526857
# direction
# 0.0017145319843450619
# glenn
# 0.0012311113571719494
# casale
# 0.0003414740483424489
# developed
# 0.0007979664032378502
# 2012,
# 0.001588771063842883
# version
# 0.0028090344246218145
# basis
# 0.0003414740483424489
# subsequent
# 0.0019438709835477483
# productions.
#
#
# 0.0003414740483424489
# mystery
# 0.0014692407994420969
# edwin
# 0.0011753926395536775
# drood
# 0.0006829480966848978
# (or
# 0.0007979664032378502
# simply
# 0.0007979664032378502
# drood)
# 0.0003414740483424489
# musical
# 0.0013387699694530314
# based
# 0.0036990983567486077
# unfinished
# 0.0003414740483424489
# charles
# 0.0014543989318156392
# dickens
# 0.0003414740483424489
# novel
# 0.0026424899820912547
# mystery
# 0.0014692407994420969
# edwin
# 0.0011753926395536775
# drood.
# 0.0003414740483424489
#
# 0.00844380941095593
# written
# 0.0035234683954146525
# rupert
# 0.0007979664032378502
# holmes,
# 0.0005876963197768388
# first
# 0.004363880864245769
# broadway
# 0.0033278807404973523
# musical
# 0.0013387699694530314
# multiple
# 0.0007979664032378502
# endings
# 0.0003414740483424489
# (determined
# 0.0003414740483424489
# audience
# 0.0011544507994853306
# vote).
# 0.0003414740483424489
# holmes
# 0.0003414740483424489
# received
# 0.003823750424675151
# tony
# 0.0047486699166035574
# awards
# 0.003880044870475363
# best
# 0.007760472490085083
# book
# 0.0022533784788526857
# musical
# 0.0013387699694530314
# best
# 0.007760472490085083
# original
# 0.004544062515786549
# score.
# 0.0011544507994853306
#
# 0.00844380941095593
# musical
# 0.0013387699694530314
# five
# 0.0017873674468232431
# tony
# 0.0047486699166035574
# awards
# 0.003880044870475363
# eleven
# 0.001588771063842883
# nominations,
# 0.0019438709835477483
# including
# 0.005274697914468527
# best
# 0.007760472490085083
# musical
# 0.0013387699694530314
# best
# 0.007760472490085083
# 0.0003414740483424489
# musical
# 0.0013387699694530314
# genius
# 0.0003414740483424489
# living
# 0.0011544507994853306
# subterranean
# 0.0003414740483424489
# labyrinth
# 0.0003414740483424489
# beneath
# 0.0003414740483424489
# paris
# 0.0009848890857375595
# opéra
# 0.0003414740483424489
# house.the
# 0.0003414740483424489
# musical
# 0.0013387699694530314
# opened
# 0.004648455978914792
# london's
# 0.0014543989318156392
# west
# 0.004740967854362197
# end
# 0.004276245051244318
# 1986,
# 0.0003414740483424489
# broadway
# 0.0033278807404973523
# 1988.
# 0.0003414740483424489
# 1986
# 0.0003414740483424489
# olivier
# 0.0030194098905266175
# award
# 0.005442493701583679
# 1988
# 0.0007979664032378502
# tony
# 0.0047486699166035574
# award
# 0.005442493701583679
# best
# 0.007760472490085083
# musical,
# 0.004264701753694729
# michael
# 0.0027892949810963243
# crawford
# 0.0003414740483424489
# (in
# 0.0003414740483424489
# title
# 0.002382435528759476
# role)
# 0.0003414740483424489
# olivier
# 0.0030194098905266175
# tony
# 0.0047486699166035574
# awards
# 0.003880044870475363
# best
# 0.007760472490085083
# actor
# 0.0017873674468232431
# musical.
# 0.003200889528647068
# longest
# 0.0009848890857375595
# running
# 0.002390318338397142
# show
# 0.005789276090102659
# broadway
# 0.0033278807404973523
# history
# 0.002048844290054693
# wide
# 0.0005876963197768388
# margin,
# 0.0003414740483424489
# celebrated
# 0.0003414740483424489
# 10,000th
# 0.0003414740483424489
# broadway
# 0.0033278807404973523
# performance
# 0.0019438709835477483
# 11
# 0.0007979664032378502
# february
# 0.002219581314225918
# 2012,
# 0.001588771063842883
# first
# 0.004363880864245769
# production
# 0.005976185995036847
# ever
# 0.0013101774757515235
# so.
# 0.0003414740483424489
# second
# 0.0020159069858734025
# longest-running
# 0.0036352210200988186
# west
# 0.004740967854362197
# end
# 0.004276245051244318
# musical,
# 0.004264701753694729
# les
# 0.0011753926395536775
# misérables,
# 0.0003414740483424489
# third
# 0.0009848890857375595
# longest-running
# 0.0036352210200988186
# west
# 0.004740967854362197
# end
# 0.004276245051244318
# show
# 0.005789276090102659
# overall,
# 0.0003414740483424489
# mousetrap.with
# 0.0003414740483424489
# total
# 0.0012311113571719494
# estimated
# 0.0005876963197768388
# worldwide
# 0.0011544507994853306
# gross
# 0.0010639552043171339
# receipts
# 0.0003414740483424489
# $5.6
# 0.0003414740483424489
# billion
# 0.0007979664032378502
# total
# 0.0012311113571719494
# broadway
# 0.0033278807404973523
# gross
# 0.0010639552043171339
# $845
# 0.0003414740483424489
# million,
# 0.0005876963197768388
# phantom
# 0.0012311113571719494
# financially
# 0.0009848890857375595
# successful
# 0.002199171257316439
# entertainment
# 0.0005876963197768388
# event
# 0.0003414740483424489
# lion
# 0.0011753926395536775
# king
# 0.002838717864128301
# surpassed
# 0.0017873674468232431
# 2014.
# 0.0019438709835477483
# 2011,
# 0.002199171257316439
# seen
# 0.0014543989318156392
# 130
# 0.0005876963197768388
# million
# 0.0022973020714655208
# people
# 0.0013101774757515235
# 145
# 0.0003414740483424489
# man
# 0.0013853409593823965
# abandoned
# 0.0003414740483424489
# years
# 0.001832642714430366
# ago.
# 0.0003414740483424489

# %% [markdown]
# ## Initializing the Model ##

# %% [markdown]
# ### Splitting into K folds ###

# %%
from sklearn.model_selection import KFold

class CorpusLoader(object):

    def __init__(self, reader, folds=10, shuffle=True, categories=None):
        self.reader = reader
        self.folds  = KFold(n_splits=folds, shuffle=shuffle)

    def fileids(self, idx=None):
        if idx is None:
            return self.files
        return self.files[idx]

    def documents(self, idx=None):
        for fileid in self.fileids(idx):
            yield list(self.reader.docs(fileids=[fileid]))

    def labels(self, idx=None):
        return [
            self.reader.categories(fileids=[fileid])[0]
            for fileid in self.fileids(idx)
        ]

    def __iter__(self):
            for train_index, test_index in self.folds.split(self.files):
                X_train = self.documents(train_index)
                y_train = self.labels(train_index)

                X_test = self.documents(test_index)
                y_test = self.labels(test_index)

                yield X_train, X_test, y_train, y_test

# %%
CorpusLoader(reviews_nonstop)

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer

def identity(words):
    return words

def create_pipeline(estimator, reduction=False):

    steps = [
        ('normalize', TextNormalizer()),
        ('vectorize', TfidfVectorizer(
            tokenizer=identity, preprocessor=None, lowercase=False
        ))
    ]

    if reduction:
        steps.append((
            'reduction', TruncatedSVD(n_components=10000)
        ))

    # Add the estimator
    steps.append(('classifier', estimator))
    return Pipeline(steps)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier

models = []
for form in (LogisticRegression, MultinomialNB, SGDClassifier):
    models.append(create_pipeline(form(), True))
    models.append(create_pipeline(form(), False))

# %%
for model in models:
    model.fit(train_docs, train_labels)

# %% [markdown]
# ## Set up for splits ##

# %% [markdown]
# ## Analysis ##

# %% [markdown]
# ###  Distribution of Sentiment Scores ###

# %%
#Exporting sentimentalities as a csv file
pd.DataFrame.to_csv(summary_sentimentality,'summary_sentimentality.csv')

# %%
#Distribution of Wikipedia Sentimentalities
plot=summary_sentimentality['Sentimentality'].hist()
plot.set_xlabel("Sentimentality")
plot.set_ylabel("Frequency")
plot.set_title("Distribution of Wikipedia Summary Sentimentalities")

plt.show()

# %%
summary_sentimentality.head(10) #lowest sentimentalities
summary_sentimentality.tail(10) #top sentimentalities

#Number of weeks each show was on Broadway
weeks=pd.DataFrame(Google_Parameters['Name'].value_counts())
weeks=weeks.reset_index()
weeks=weeks.rename(index=str, columns={"index": "Name1", "Name": "Weeks"})
weeks=weeks.sort_values(by=['Name1'])
weeks=weeks.reset_index()

#Merging sentimentality and weeks on Broadway 
Wikipedia = pd.concat([weeks, summary_sentimentality], axis=1)
Wikipedia.drop(['index','Name1'],axis=1) #Clean
Wikipedia = Wikipedia[['Name', 'Weeks', 'Sentimentality']]

pd.DataFrame.to_csv(Wikipedia,'Wikipedia_Data.csv')

# %% [markdown]
# ### Weeks v. Sentimentality ###

# %%
#log transform weeks 
Wikipedia['Weeks'] = np.log(Wikipedia['Weeks'])
Wikipedia['Weeks'].hist()
plt.show()

# %%
#Scatter plot
Wikipedia.plot.scatter(x='Weeks', y='Sentimentality', rot=0)
plt.show()
